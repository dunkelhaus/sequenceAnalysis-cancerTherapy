# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
from sqlalchemy import create_engine
import sqlite3
import matplotlib.pyplot as plt

# %%
csv_database = create_engine('sqlite:///csv_database.db')

# %%
file = "/home/skjena/cancerTherapy/modules/RawDB/scripts/fm_sample_independent_transpose.csv"

# %%
print pd.read_csv(file, nrows=5)
# Out:
#          Token  lungad_10  lungad_1  lungad_11  lungad_12  lungad_13  \
# 0  3AAAAAAAAAA       1081      1793        607        827        887
# 1  3AAAAAAAAAC         36        47         21         42         21
# 2  3AAAAAAAAAG         35        45         21         29         28
# 3  3AAAAAAAAAT         31        29         12         25         29
# 4  3AAAAAAAACA         20        21         14         18         14
#
#    lungad_14  lungad_15  lungad_16  lungad_17     ...      melanoma_62  \
# 0       1147        669       1039       2932     ...             1143
# 1         18         34         25         96     ...               35
# 2         21         39         31        129     ...               44
# 3         17         24         19        116     ...               37
# 4         13         18         12         54     ...               16
#
#    melanoma_63  melanoma_64  melanoma_65  melanoma_66  melanoma_67  \
# ...

# %%
chunksize = 100000
i = 0
j = 1
for df in pd.read_csv(file, chunksize=chunksize, iterator=True):
      df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
      df.index += j
      i+=1
      df.to_sql('mutations', csv_database, if_exists='append')
      j = df.index[-1] + 1

# %%
csv_database.execute('select Token from mutations').fetchall()
# Out:
# [(u'3AAAAAAAAAA',),
#  (u'3AAAAAAAAAC',),
#  (u'3AAAAAAAAAG',),
#  (u'3AAAAAAAAAT',),
#  (u'3AAAAAAAACA',),
#  (u'3AAAAAAAACC',),
#  (u'3AAAAAAAACG',),
#  (u'3AAAAAAAACT',),
#  (u'3AAAAAAAAGA',),
#  (u'3AAAAAAAAGC',),
#  (u'3AAAAAAAAGG',),
#  (u'3AAAAAAAAGT',),
#  (u'3AAAAAAAATA',),
#  (u'3AAAAAAAATC',),
#  (u'3AAAAAAAATG',),
#  (u'3AAAAAAAATT',),
#  (u'3AAAAAAACAA',),
#  (u'3AAAAAAACAC',),
#  (u'3AAAAAAACAG',),
#  (u'3AAAAAAACAT',),
#  (u'3AAAAAAACCA',),
#  (u'3AAAAAAACCC',),
#  (u'3AAAAAAACCT',),
#  (u'3AAAAAAACGG',),
#  (u'3AAAAAAACTA',),
#  (u'3AAAAAAACTC',),
#  (u'3AAAAAAACTG',),
#  (u'3AAAAAAACTT',),
#  (u'3AAAAAAAGAA',),
#  (u'3AAAAAAAGAC',),
#  (u'3AAAAAAAGAG',),
#  (u'3AAAAAAAGAT',),
#  (u'3AAAAAAAGCC',),
#  (u'3AAAAAAAGCT',),
#  (u'3AAAAAAAGGA',),
#  (u'3AAAAAAAGGC',),
#  (u'3AAAAAAAGGG',),
#  (u'3AAAAAAAGGT',),
#  (u'3AAAAAAAGTA',),
#  (u'3AAAAAAAGTG',),
#  (u'3AAAAAAAGTT',),
#  (u'3AAAAAAATAA',),
#  (u'3AAAAAAATAC',),
#  (u'3AAAAAAATAG',),
#  (u'3AAAAAAATAT',),
# ...

# %%
csv_database.execute("PRAGMA table_info(mutations)").fetchall()
# Out:
# [(0, u'index', u'BIGINT', 0, None, 0),
#  (1, u'Token', u'TEXT', 0, None, 0),
#  (2, u'lungad_10', u'BIGINT', 0, None, 0),
#  (3, u'lungad_1', u'FLOAT', 0, None, 0),
#  (4, u'lungad_11', u'FLOAT', 0, None, 0),
#  (5, u'lungad_12', u'FLOAT', 0, None, 0),
#  (6, u'lungad_13', u'FLOAT', 0, None, 0),
#  (7, u'lungad_14', u'FLOAT', 0, None, 0),
#  (8, u'lungad_15', u'FLOAT', 0, None, 0),
#  (9, u'lungad_16', u'FLOAT', 0, None, 0),
#  (10, u'lungad_17', u'FLOAT', 0, None, 0),
#  (11, u'lungad_18', u'FLOAT', 0, None, 0),
#  (12, u'lungad_19', u'FLOAT', 0, None, 0),
#  (13, u'lungad_20', u'FLOAT', 0, None, 0),
#  (14, u'lungad_2', u'FLOAT', 0, None, 0),
#  (15, u'lungad_21', u'FLOAT', 0, None, 0),
#  (16, u'lungad_22', u'FLOAT', 0, None, 0),
#  (17, u'lungad_23', u'FLOAT', 0, None, 0),
#  (18, u'lungad_24', u'FLOAT', 0, None, 0),
#  (19, u'lungad_25', u'FLOAT', 0, None, 0),
#  (20, u'lungad_26', u'FLOAT', 0, None, 0),
#  (21, u'lungad_27', u'FLOAT', 0, None, 0),
# ...

# %%
lungad_1df = pd.read_sql_query('select Token, lungad_1 from mutations',csv_database)
lungad_11df = pd.read_sql_query('select Token, lungad_11 from mutations',csv_database)
lungad_12df = pd.read_sql_query('select Token, lungad_12 from mutations',csv_database)
lungad_13df = pd.read_sql_query('select Token, lungad_13 from mutations',csv_database)
lungad_14df = pd.read_sql_query('select Token, lungad_14 from mutations',csv_database)
lungad_15df = pd.read_sql_query('select Token, lungad_15 from mutations',csv_database)
lungad_16df = pd.read_sql_query('select Token, lungad_16 from mutations',csv_database)
lungad_17df = pd.read_sql_query('select Token, lungad_17 from mutations',csv_database)
lungad_18df = pd.read_sql_query('select Token, lungad_18 from mutations',csv_database)
lungad_19df = pd.read_sql_query('select Token, lungad_19 from mutations',csv_database)
lungad_20df = pd.read_sql_query('select Token, lungad_20 from mutations',csv_database)

# %%
lungad_2df = pd.read_sql_query('select Token, lungad_2 from mutations',csv_database)
lungad_21df = pd.read_sql_query('select Token, lungad_21 from mutations',csv_database)
lungad_22df = pd.read_sql_query('select Token, lungad_22 from mutations',csv_database)
lungad_23df = pd.read_sql_query('select Token, lungad_23 from mutations',csv_database)
lungad_24df = pd.read_sql_query('select Token, lungad_24 from mutations',csv_database)
lungad_25df = pd.read_sql_query('select Token, lungad_25 from mutations',csv_database)
lungad_26df = pd.read_sql_query('select Token, lungad_26 from mutations',csv_database)
lungad_27df = pd.read_sql_query('select Token, lungad_27 from mutations',csv_database)
lungad_28df = pd.read_sql_query('select Token, lungad_28 from mutations',csv_database)
lungad_29df = pd.read_sql_query('select Token, lungad_29 from mutations',csv_database)
lungad_30df = pd.read_sql_query('select Token, lungad_30 from mutations',csv_database)

# %%
lungad_3df = pd.read_sql_query('select Token, lungad_3 from mutations',csv_database)
lungad_31df = pd.read_sql_query('select Token, lungad_31 from mutations',csv_database)
lungad_32df = pd.read_sql_query('select Token, lungad_32 from mutations',csv_database)
lungad_33df = pd.read_sql_query('select Token, lungad_33 from mutations',csv_database)
lungad_34df = pd.read_sql_query('select Token, lungad_34 from mutations',csv_database)
lungad_35df = pd.read_sql_query('select Token, lungad_35 from mutations',csv_database)
lungad_36df = pd.read_sql_query('select Token, lungad_36 from mutations',csv_database)
lungad_37df = pd.read_sql_query('select Token, lungad_37 from mutations',csv_database)
lungad_38df = pd.read_sql_query('select Token, lungad_38 from mutations',csv_database)
lungad_39df = pd.read_sql_query('select Token, lungad_39 from mutations',csv_database)
lungad_40df = pd.read_sql_query('select Token, lungad_40 from mutations',csv_database)

# %%
lungad_4df = pd.read_sql_query('select Token, lungad_4 from mutations',csv_database)
lungad_41df = pd.read_sql_query('select Token, lungad_41 from mutations',csv_database)
lungad_42df = pd.read_sql_query('select Token, lungad_42 from mutations',csv_database)
lungad_5df = pd.read_sql_query('select Token, lungad_5 from mutations',csv_database)
lungad_6df = pd.read_sql_query('select Token, lungad_6 from mutations',csv_database)
lungad_7df = pd.read_sql_query('select Token, lungad_7 from mutations',csv_database)
lungad_8df = pd.read_sql_query('select Token, lungad_8 from mutations',csv_database)
lungad_9df = pd.read_sql_query('select Token, lungad_9 from mutations',csv_database)

# %%
lungad_10df =pd.read_sql_query('select Token, lungad_10 from mutations',csv_database)

# %%
melanoma_10df = pd.read_sql_query('select Token, melanoma_10 from mutations',csv_database)
melanoma_1df = pd.read_sql_query('select Token, melanoma_1 from mutations',csv_database)
melanoma_11df = pd.read_sql_query('select Token, melanoma_11 from mutations',csv_database)
melanoma_12df = pd.read_sql_query('select Token, melanoma_12 from mutations',csv_database)
melanoma_13df = pd.read_sql_query('select Token, melanoma_13 from mutations',csv_database)
melanoma_14df = pd.read_sql_query('select Token, melanoma_14 from mutations',csv_database)
melanoma_15df = pd.read_sql_query('select Token, melanoma_15 from mutations',csv_database)
melanoma_16df = pd.read_sql_query('select Token, melanoma_16 from mutations',csv_database)
melanoma_17df = pd.read_sql_query('select Token, melanoma_17 from mutations',csv_database)
melanoma_18df = pd.read_sql_query('select Token, melanoma_18 from mutations',csv_database)
melanoma_19df = pd.read_sql_query('select Token, melanoma_19 from mutations',csv_database)
melanoma_20df = pd.read_sql_query('select Token, melanoma_20 from mutations',csv_database)

# %%
melanoma_2df = pd.read_sql_query('select Token, melanoma_2 from mutations',csv_database)
melanoma_21df = pd.read_sql_query('select Token, melanoma_21 from mutations',csv_database)
melanoma_22df = pd.read_sql_query('select Token, melanoma_22 from mutations',csv_database)
melanoma_23df = pd.read_sql_query('select Token, melanoma_23 from mutations',csv_database)
melanoma_24df = pd.read_sql_query('select Token, melanoma_24 from mutations',csv_database)
melanoma_25df = pd.read_sql_query('select Token, melanoma_25 from mutations',csv_database)
melanoma_26df = pd.read_sql_query('select Token, melanoma_26 from mutations',csv_database)
melanoma_27df = pd.read_sql_query('select Token, melanoma_27 from mutations',csv_database)
melanoma_28df = pd.read_sql_query('select Token, melanoma_28 from mutations',csv_database)
melanoma_29df = pd.read_sql_query('select Token, melanoma_29 from mutations',csv_database)
melanoma_30df = pd.read_sql_query('select Token, melanoma_30 from mutations',csv_database)

# %%
melanoma_3df = pd.read_sql_query('select Token, melanoma_3 from mutations',csv_database)
melanoma_31df = pd.read_sql_query('select Token, melanoma_31 from mutations',csv_database)
melanoma_32df = pd.read_sql_query('select Token, melanoma_32 from mutations',csv_database)
melanoma_33df = pd.read_sql_query('select Token, melanoma_33 from mutations',csv_database)
melanoma_34df = pd.read_sql_query('select Token, melanoma_34 from mutations',csv_database)
melanoma_35df = pd.read_sql_query('select Token, melanoma_35 from mutations',csv_database)
melanoma_36df = pd.read_sql_query('select Token, melanoma_36 from mutations',csv_database)
melanoma_37df = pd.read_sql_query('select Token, melanoma_37 from mutations',csv_database)
melanoma_38df = pd.read_sql_query('select Token, melanoma_38 from mutations',csv_database)
melanoma_39df = pd.read_sql_query('select Token, melanoma_39 from mutations',csv_database)
melanoma_40df = pd.read_sql_query('select Token, melanoma_40 from mutations',csv_database)

# %%
melanoma_4df = pd.read_sql_query('select Token, melanoma_4 from mutations',csv_database)
melanoma_41df = pd.read_sql_query('select Token, melanoma_41 from mutations',csv_database)
melanoma_42df = pd.read_sql_query('select Token, melanoma_42 from mutations',csv_database)
melanoma_43df = pd.read_sql_query('select Token, melanoma_43 from mutations',csv_database)
melanoma_44df = pd.read_sql_query('select Token, melanoma_44 from mutations',csv_database)
melanoma_45df = pd.read_sql_query('select Token, melanoma_45 from mutations',csv_database)
melanoma_46df = pd.read_sql_query('select Token, melanoma_46 from mutations',csv_database)
melanoma_47df = pd.read_sql_query('select Token, melanoma_47 from mutations',csv_database)
melanoma_48df = pd.read_sql_query('select Token, melanoma_48 from mutations',csv_database)
melanoma_49df = pd.read_sql_query('select Token, melanoma_49 from mutations',csv_database)
melanoma_50df = pd.read_sql_query('select Token, melanoma_50 from mutations',csv_database)

# %%
melanoma_5df = pd.read_sql_query('select Token, melanoma_5 from mutations',csv_database)
melanoma_51df = pd.read_sql_query('select Token, melanoma_51 from mutations',csv_database)
melanoma_52df = pd.read_sql_query('select Token, melanoma_52 from mutations',csv_database)
melanoma_53df = pd.read_sql_query('select Token, melanoma_53 from mutations',csv_database)
melanoma_54df = pd.read_sql_query('select Token, melanoma_54 from mutations',csv_database)
melanoma_55df = pd.read_sql_query('select Token, melanoma_55 from mutations',csv_database)
melanoma_56df = pd.read_sql_query('select Token, melanoma_56 from mutations',csv_database)
melanoma_57df = pd.read_sql_query('select Token, melanoma_57 from mutations',csv_database)
melanoma_58df = pd.read_sql_query('select Token, melanoma_58 from mutations',csv_database)
melanoma_59df = pd.read_sql_query('select Token, melanoma_59 from mutations',csv_database)
melanoma_60df = pd.read_sql_query('select Token, melanoma_60 from mutations',csv_database)

# %%
melanoma_6df = pd.read_sql_query('select Token, melanoma_6 from mutations',csv_database)
melanoma_61df = pd.read_sql_query('select Token, melanoma_61 from mutations',csv_database)
melanoma_62df = pd.read_sql_query('select Token, melanoma_62 from mutations',csv_database)
melanoma_63df = pd.read_sql_query('select Token, melanoma_63 from mutations',csv_database)
melanoma_64df = pd.read_sql_query('select Token, melanoma_64 from mutations',csv_database)
melanoma_65df = pd.read_sql_query('select Token, melanoma_65 from mutations',csv_database)
melanoma_66df = pd.read_sql_query('select Token, melanoma_66 from mutations',csv_database)
melanoma_67df = pd.read_sql_query('select Token, melanoma_67 from mutations',csv_database)
melanoma_68df = pd.read_sql_query('select Token, melanoma_68 from mutations',csv_database)

# %%
melanoma_7df = pd.read_sql_query('select Token, melanoma_7 from mutations',csv_database)
melanoma_8df = pd.read_sql_query('select Token, melanoma_8 from mutations',csv_database)
melanoma_9df = pd.read_sql_query('select Token, melanoma_9 from mutations',csv_database)

# %%
sortedmelanoma_1 = melanoma_1df.sort_values('melanoma_1', ascending=False)
sortedmelanoma_2 = melanoma_2df.sort_values('melanoma_2', ascending=False)
sortedmelanoma_3 = melanoma_3df.sort_values('melanoma_3', ascending=False)
sortedmelanoma_4 = melanoma_4df.sort_values('melanoma_4', ascending=False)
sortedmelanoma_5 = melanoma_5df.sort_values('melanoma_5', ascending=False)
sortedmelanoma_6 = melanoma_6df.sort_values('melanoma_6', ascending=False)
sortedmelanoma_7 = melanoma_7df.sort_values('melanoma_7', ascending=False)
sortedmelanoma_8 = melanoma_8df.sort_values('melanoma_8', ascending=False)
sortedmelanoma_9 = melanoma_9df.sort_values('melanoma_9', ascending=False)
sortedmelanoma_10 = melanoma_10df.sort_values('melanoma_10', ascending=False)

# %%
sortedmelanoma_11 = melanoma_11df.sort_values('melanoma_11', ascending=False)
sortedmelanoma_12 = melanoma_12df.sort_values('melanoma_12', ascending=False)
sortedmelanoma_13 = melanoma_13df.sort_values('melanoma_13', ascending=False)
sortedmelanoma_14 = melanoma_14df.sort_values('melanoma_14', ascending=False)
sortedmelanoma_15 = melanoma_15df.sort_values('melanoma_15', ascending=False)
sortedmelanoma_16 = melanoma_16df.sort_values('melanoma_16', ascending=False)
sortedmelanoma_17 = melanoma_17df.sort_values('melanoma_17', ascending=False)
sortedmelanoma_18 = melanoma_18df.sort_values('melanoma_18', ascending=False)
sortedmelanoma_19 = melanoma_19df.sort_values('melanoma_19', ascending=False)
sortedmelanoma_20 = melanoma_20df.sort_values('melanoma_20', ascending=False)

# %%
sortedmelanoma_21 = melanoma_21df.sort_values('melanoma_21', ascending=False)
sortedmelanoma_22 = melanoma_22df.sort_values('melanoma_22', ascending=False)
sortedmelanoma_23 = melanoma_23df.sort_values('melanoma_23', ascending=False)
sortedmelanoma_24 = melanoma_24df.sort_values('melanoma_24', ascending=False)
sortedmelanoma_25 = melanoma_25df.sort_values('melanoma_25', ascending=False)
sortedmelanoma_26 = melanoma_26df.sort_values('melanoma_26', ascending=False)
sortedmelanoma_27 = melanoma_27df.sort_values('melanoma_27', ascending=False)
sortedmelanoma_28 = melanoma_28df.sort_values('melanoma_28', ascending=False)
sortedmelanoma_29 = melanoma_29df.sort_values('melanoma_29', ascending=False)
sortedmelanoma_30 = melanoma_30df.sort_values('melanoma_30', ascending=False)

# %%
sortedmelanoma_31 = melanoma_31df.sort_values('melanoma_31', ascending=False)
sortedmelanoma_32 = melanoma_32df.sort_values('melanoma_32', ascending=False)
sortedmelanoma_33 = melanoma_33df.sort_values('melanoma_33', ascending=False)
sortedmelanoma_34 = melanoma_34df.sort_values('melanoma_34', ascending=False)
sortedmelanoma_35 = melanoma_35df.sort_values('melanoma_35', ascending=False)
sortedmelanoma_36 = melanoma_36df.sort_values('melanoma_36', ascending=False)
sortedmelanoma_37 = melanoma_37df.sort_values('melanoma_37', ascending=False)
sortedmelanoma_38 = melanoma_38df.sort_values('melanoma_38', ascending=False)
sortedmelanoma_39 = melanoma_39df.sort_values('melanoma_39', ascending=False)
sortedmelanoma_40 = melanoma_40df.sort_values('melanoma_40', ascending=False)

# %%
sortedmelanoma_41 = melanoma_41df.sort_values('melanoma_41', ascending=False)
sortedmelanoma_42 = melanoma_42df.sort_values('melanoma_42', ascending=False)
sortedmelanoma_43 = melanoma_43df.sort_values('melanoma_43', ascending=False)
sortedmelanoma_44 = melanoma_44df.sort_values('melanoma_44', ascending=False)
sortedmelanoma_45 = melanoma_45df.sort_values('melanoma_45', ascending=False)
sortedmelanoma_46 = melanoma_46df.sort_values('melanoma_46', ascending=False)
sortedmelanoma_47 = melanoma_47df.sort_values('melanoma_47', ascending=False)
sortedmelanoma_48 = melanoma_48df.sort_values('melanoma_48', ascending=False)
sortedmelanoma_49 = melanoma_49df.sort_values('melanoma_49', ascending=False)
sortedmelanoma_50 = melanoma_50df.sort_values('melanoma_50', ascending=False)

# %%
sortedmelanoma_51 = melanoma_51df.sort_values('melanoma_51', ascending=False)
sortedmelanoma_52 = melanoma_52df.sort_values('melanoma_52', ascending=False)
sortedmelanoma_53 = melanoma_53df.sort_values('melanoma_53', ascending=False)
sortedmelanoma_54 = melanoma_54df.sort_values('melanoma_54', ascending=False)
sortedmelanoma_55 = melanoma_55df.sort_values('melanoma_55', ascending=False)
sortedmelanoma_56 = melanoma_56df.sort_values('melanoma_56', ascending=False)
sortedmelanoma_57 = melanoma_57df.sort_values('melanoma_57', ascending=False)
sortedmelanoma_58 = melanoma_58df.sort_values('melanoma_58', ascending=False)
sortedmelanoma_59 = melanoma_59df.sort_values('melanoma_59', ascending=False)
sortedmelanoma_60 = melanoma_60df.sort_values('melanoma_60', ascending=False)

# %%
sortedmelanoma_61 = melanoma_61df.sort_values('melanoma_61', ascending=False)
sortedmelanoma_62 = melanoma_62df.sort_values('melanoma_62', ascending=False)
sortedmelanoma_63 = melanoma_63df.sort_values('melanoma_63', ascending=False)
sortedmelanoma_64 = melanoma_64df.sort_values('melanoma_64', ascending=False)
sortedmelanoma_65 = melanoma_65df.sort_values('melanoma_65', ascending=False)
sortedmelanoma_66 = melanoma_66df.sort_values('melanoma_66', ascending=False)
sortedmelanoma_67 = melanoma_67df.sort_values('melanoma_67', ascending=False)
sortedmelanoma_68 = melanoma_68df.sort_values('melanoma_68', ascending=False)

# %%
sortedmelanoma_7 = melanoma_7df.sort_values('melanoma_7', ascending=False)
sortedmelanoma_8 = melanoma_8df.sort_values('melanoma_8', ascending=False)
sortedmelanoma_9 = melanoma_9df.sort_values('melanoma_9', ascending=False)

# %%
sortedmelanoma_9
# Out:
#                Token  melanoma_9
# 137352           C>T     23028.0
# 137354           T>C     16593.0
# 137353           T>A     12219.0
# 137355           T>G     10037.0
# 137350           C>A      9882.0
# 0        3AAAAAAAAAA      3615.0
# 68289    3TTTTTTTTTT      3505.0
# 137351           C>G      3203.0
# 68290    5AAAAAAAAAA      2114.0
# 137349   5TTTTTTTTTT      1676.0
# 53741    3TATATATATA       928.0
# 121114   5TATATATATA       872.0
# 14784    3ATATATATAT       759.0
# 5602     3ACACACACAC       734.0
# 117209   5GTGTGTGTGT       720.0
# 83217    5ATATATATAT       702.0
# 63080    3TGTGTGTGTG       565.0
# 88479    5CACACACACA       558.0
# 131190   5TGTGTGTGTG       329.0
# 19951    3CACACACACA       300.0
# 99672    5CTCTCTCTCT       278.0
# 9502     3AGAGAGAGAG       262.0
# 134013   5TTCTTTCTTT       254.0
# 49731    3GTGTGTGTGT       233.0
# 67874    3TTTTCTTTTT       232.0
# 74264    5ACACACACAC       223.0
# 1064     3AAAGAAAGAA       210.0
# ...

# %%
sortedlungad_1 = lungad_1df.sort_values('lungad_1', ascending=False)
sortedlungad_2 = lungad_2df.sort_values('lungad_2', ascending=False)
sortedlungad_3 = lungad_3df.sort_values('lungad_3', ascending=False)
sortedlungad_4 = lungad_4df.sort_values('lungad_4', ascending=False)
sortedlungad_5 = lungad_5df.sort_values('lungad_5', ascending=False)
sortedlungad_6 = lungad_6df.sort_values('lungad_6', ascending=False)
sortedlungad_7 = lungad_7df.sort_values('lungad_7', ascending=False)
sortedlungad_8 = lungad_8df.sort_values('lungad_8', ascending=False)
sortedlungad_9 = lungad_9df.sort_values('lungad_9', ascending=False)
sortedlungad_10 = lungad_10df.sort_values('lungad_10', ascending=False)

# %%
sortedlungad_11 = lungad_11df.sort_values('lungad_11', ascending=False)
sortedlungad_12 = lungad_12df.sort_values('lungad_12', ascending=False)
sortedlungad_13 = lungad_13df.sort_values('lungad_13', ascending=False)
sortedlungad_14 = lungad_14df.sort_values('lungad_14', ascending=False)
sortedlungad_15 = lungad_15df.sort_values('lungad_15', ascending=False)
sortedlungad_16 = lungad_16df.sort_values('lungad_16', ascending=False)
sortedlungad_17 = lungad_17df.sort_values('lungad_17', ascending=False)
sortedlungad_18 = lungad_18df.sort_values('lungad_18', ascending=False)
sortedlungad_19 = lungad_19df.sort_values('lungad_19', ascending=False)
sortedlungad_20 = lungad_20df.sort_values('lungad_20', ascending=False)

# %%
sortedlungad_21 = lungad_21df.sort_values('lungad_21', ascending=False)
sortedlungad_22 = lungad_22df.sort_values('lungad_22', ascending=False)
sortedlungad_23 = lungad_23df.sort_values('lungad_23', ascending=False)
sortedlungad_24 = lungad_24df.sort_values('lungad_24', ascending=False)
sortedlungad_25 = lungad_25df.sort_values('lungad_25', ascending=False)
sortedlungad_26 = lungad_26df.sort_values('lungad_26', ascending=False)
sortedlungad_27 = lungad_27df.sort_values('lungad_27', ascending=False)
sortedlungad_28 = lungad_28df.sort_values('lungad_28', ascending=False)
sortedlungad_29 = lungad_29df.sort_values('lungad_29', ascending=False)
sortedlungad_30 = lungad_30df.sort_values('lungad_30', ascending=False)

# %%
sortedlungad_31 = lungad_31df.sort_values('lungad_31', ascending=False)
sortedlungad_32 = lungad_32df.sort_values('lungad_32', ascending=False)
sortedlungad_33 = lungad_33df.sort_values('lungad_33', ascending=False)
sortedlungad_34 = lungad_34df.sort_values('lungad_34', ascending=False)
sortedlungad_35 = lungad_35df.sort_values('lungad_35', ascending=False)
sortedlungad_36 = lungad_36df.sort_values('lungad_36', ascending=False)
sortedlungad_37 = lungad_37df.sort_values('lungad_37', ascending=False)
sortedlungad_38 = lungad_38df.sort_values('lungad_38', ascending=False)
sortedlungad_39 = lungad_39df.sort_values('lungad_39', ascending=False)
sortedlungad_40 = lungad_40df.sort_values('lungad_40', ascending=False)

# %%
sortedlungad_41 = lungad_41df.sort_values('lungad_41', ascending=False)
sortedlungad_42 = lungad_42df.sort_values('lungad_42', ascending=False)

# %%
melanoma_1 = sortedmelanoma_1['Token']
melanoma_1val = sortedmelanoma_1['melanoma_1']
# %store melanoma_1 >> melanomaresult.csv
# %store melanoma_1val >> melanomavalue.csv

melanoma_2 = sortedmelanoma_2['Token']
melanoma_2val = sortedmelanoma_2['melanoma_2']
# %store melanoma_2 >> melanomaresult.csv
# %store melanoma_2val >> melanomavalue.csv

melanoma_3 = sortedmelanoma_3['Token']
melanoma_3val = sortedmelanoma_3['melanoma_3']
# %store melanoma_3 >> melanomaresult.csv
# %store melanoma_3val >> melanomavalue.csv

melanoma_4 = sortedmelanoma_4['Token']
melanoma_4val = sortedmelanoma_4['melanoma_4']
# %store melanoma_4 >> melanomaresult.csv
# %store melanoma_4val >> melanomavalue.csv

melanoma_5 = sortedmelanoma_5['Token']
melanoma_5val = sortedmelanoma_5['melanoma_5']
# %store melanoma_5 >> melanomaresult.csv
# %store melanoma_5val >> melanomavalue.csv

melanoma_6 = sortedmelanoma_6['Token']
melanoma_6val = sortedmelanoma_6['melanoma_6']
# %store melanoma_6 >> melanomaresult.csv
# %store melanoma_6val >> melanomavalue.csv

melanoma_7 = sortedmelanoma_7['Token']
melanoma_7val = sortedmelanoma_7['melanoma_7']
# %store melanoma_7 >> melanomaresult.csv
# %store melanoma_7val >> melanomavalue.csv

melanoma_8 = sortedmelanoma_8['Token']
melanoma_8val = sortedmelanoma_8['melanoma_8']
# %store melanoma_8 >> melanomaresult.csv
# %store melanoma_8val >> melanomavalue.csv

melanoma_9 = sortedmelanoma_9['Token']
melanoma_9val = sortedmelanoma_9['melanoma_9']
# %store melanoma_9 >> melanomaresult.csv
# %store melanoma_9val >> melanomavalue.csv

melanoma_10 = sortedmelanoma_10['Token']
melanoma_10val = sortedmelanoma_10['melanoma_10']
# %store melanoma_10 >> melanomaresult.csv
# %store melanoma_10val >> melanomavalue.csv

melanoma_11 = sortedmelanoma_11['Token']
melanoma_11val = sortedmelanoma_11['melanoma_11']
# %store melanoma_11 >> melanomaresult.csv
# %store melanoma_11val >> melanomavalue.csv

melanoma_12 = sortedmelanoma_12['Token']
melanoma_12val = sortedmelanoma_12['melanoma_12']
# %store melanoma_12 >> melanomaresult.csv
# %store melanoma_12val >> melanomavalue.csv

melanoma_13 = sortedmelanoma_13['Token']
melanoma_13val = sortedmelanoma_13['melanoma_13']
# %store melanoma_13 >> melanomaresult.csv
# %store melanoma_13val >> melanomavalue.csv

melanoma_14 = sortedmelanoma_14['Token']
melanoma_14val = sortedmelanoma_14['melanoma_14']
# %store melanoma_14 >> melanomaresult.csv
# %store melanoma_14val >> melanomavalue.csv

melanoma_15 = sortedmelanoma_15['Token']
melanoma_15val = sortedmelanoma_15['melanoma_15']
# %store melanoma_15 >> melanomaresult.csv
# %store melanoma_15val >> melanomavalue.csv

melanoma_16 = sortedmelanoma_16['Token']
melanoma_16val = sortedmelanoma_16['melanoma_16']
# %store melanoma_16 >> melanomaresult.csv
# %store melanoma_16val >> melanomavalue.csv

melanoma_17 = sortedmelanoma_17['Token']
melanoma_17val = sortedmelanoma_17['melanoma_17']
# %store melanoma_17 >> melanomaresult.csv
# %store melanoma_17val >> melanomavalue.csv

melanoma_18 = sortedmelanoma_18['Token']
melanoma_18val = sortedmelanoma_18['melanoma_18']
# %store melanoma_18 >> melanomaresult.csv
# %store melanoma_18val >> melanomavalue.csv

melanoma_19 = sortedmelanoma_19['Token']
melanoma_19val = sortedmelanoma_19['melanoma_19']
# %store melanoma_19 >> melanomaresult.csv
# %store melanoma_19val >> melanomavalue.csv

melanoma_20 = sortedmelanoma_20['Token']
melanoma_20val = sortedmelanoma_20['melanoma_20']
# %store melanoma_20 >> melanomaresult.csv
# %store melanoma_20val >> melanomavalue.csv

melanoma_21 = sortedmelanoma_21['Token']
melanoma_21val = sortedmelanoma_21['melanoma_21']
# %store melanoma_21 >> melanomaresult.csv
# %store melanoma_21val >> melanomavalue.csv

melanoma_22 = sortedmelanoma_22['Token']
melanoma_22val = sortedmelanoma_22['melanoma_22']
# %store melanoma_22 >> melanomaresult.csv
# %store melanoma_22val >> melanomavalue.csv

melanoma_23 = sortedmelanoma_23['Token']
melanoma_23val = sortedmelanoma_23['melanoma_23']
# %store melanoma_23 >> melanomaresult.csv
# %store melanoma_23val >> melanomavalue.csv

melanoma_24 = sortedmelanoma_24['Token']
melanoma_24val = sortedmelanoma_24['melanoma_24']
# %store melanoma_24 >> melanomaresult.csv
# %store melanoma_24val >> melanomavalue.csv

melanoma_25 = sortedmelanoma_25['Token']
melanoma_25val = sortedmelanoma_25['melanoma_25']
# %store melanoma_25 >> melanomaresult.csv
# %store melanoma_25val >> melanomavalue.csv

melanoma_26 = sortedmelanoma_26['Token']
melanoma_26val = sortedmelanoma_26['melanoma_26']
# %store melanoma_26 >> melanomaresult.csv
# %store melanoma_26val >> melanomavalue.csv

melanoma_27 = sortedmelanoma_27['Token']
melanoma_27val = sortedmelanoma_27['melanoma_27']
# %store melanoma_27 >> melanomaresult.csv
# %store melanoma_27val >> melanomavalue.csv

melanoma_28 = sortedmelanoma_28['Token']
melanoma_28val = sortedmelanoma_28['melanoma_28']
# %store melanoma_28 >> melanomaresult.csv
# %store melanoma_28val >> melanomavalue.csv

melanoma_29 = sortedmelanoma_29['Token']
melanoma_29val = sortedmelanoma_29['melanoma_29']
# %store melanoma_29 >> melanomaresult.csv
# %store melanoma_29val >> melanomavalue.csv

melanoma_30 = sortedmelanoma_30['Token']
melanoma_30val = sortedmelanoma_30['melanoma_30']
# %store melanoma_30 >> melanomaresult.csv
# %store melanoma_30val >> melanomavalue.csv

melanoma_31 = sortedmelanoma_31['Token']
melanoma_31val = sortedmelanoma_31['melanoma_31']
# %store melanoma_31 >> melanomaresult.csv
# %store melanoma_31val >> melanomavalue.csv

melanoma_32 = sortedmelanoma_32['Token']
melanoma_32val = sortedmelanoma_32['melanoma_32']
# %store melanoma_32 >> melanomaresult.csv
# %store melanoma_2val >> melanomavalue.csv

melanoma_33 = sortedmelanoma_33['Token']
melanoma_33val = sortedmelanoma_33['melanoma_33']
# %store melanoma_33 >> melanomaresult.csv
# %store melanoma_33val >> melanomavalue.csv

melanoma_34 = sortedmelanoma_34['Token']
melanoma_34val = sortedmelanoma_34['melanoma_34']
# %store melanoma_34 >> melanomaresult.csv
# %store melanoma_34val >> melanomavalue.csv

melanoma_35 = sortedmelanoma_35['Token']
melanoma_35val = sortedmelanoma_35['melanoma_35']
# %store melanoma_35 >> melanomaresult.csv
# %store melanoma_35val >> melanomavalue.csv

melanoma_36 = sortedmelanoma_36['Token']
melanoma_36val = sortedmelanoma_36['melanoma_36']
# %store melanoma_36 >> melanomaresult.csv
# %store melanoma_36val >> melanomavalue.csv

melanoma_37 = sortedmelanoma_37['Token']
melanoma_37val = sortedmelanoma_37['melanoma_37']
# %store melanoma_37 >> melanomaresult.csv
# %store melanoma_37val >> melanomavalue.csv

melanoma_38 = sortedmelanoma_38['Token']
melanoma_38val = sortedmelanoma_38['melanoma_38']
# %store melanoma_38 >> melanomaresult.csv
# %store melanoma_38val >> melanomavalue.csv

melanoma_39 = sortedmelanoma_39['Token']
melanoma_39val = sortedmelanoma_39['melanoma_39']
# %store melanoma_39 >> melanomaresult.csv
# %store melanoma_39val >> melanomavalue.csv

melanoma_40 = sortedmelanoma_40['Token']
melanoma_40val = sortedmelanoma_40['melanoma_40']
# %store melanoma_40 >> melanomaresult.csv
# %store melanoma_40val >> melanomavalue.csv

melanoma_41 = sortedmelanoma_41['Token']
melanoma_41val = sortedmelanoma_41['melanoma_41']
# %store melanoma_41 >> melanomaresult.csv
# %store melanoma_41val >> melanomavalue.csv

melanoma_42 = sortedmelanoma_42['Token']
melanoma_42val = sortedmelanoma_42['melanoma_42']
# %store melanoma_42 >> melanomaresult.csv
# %store melanoma_42val >> melanomavalue.csv

melanoma_43 = sortedmelanoma_43['Token']
melanoma_43val = sortedmelanoma_43['melanoma_43']
# %store melanoma_43 >> melanomaresult.csv
# %store melanoma_43val >> melanomavalue.csv

melanoma_44 = sortedmelanoma_44['Token']
melanoma_44val = sortedmelanoma_44['melanoma_44']
# %store melanoma_44 >> melanomaresult.csv
# %store melanoma_44val >> melanomavalue.csv

melanoma_45 = sortedmelanoma_45['Token']
melanoma_45val = sortedmelanoma_45['melanoma_45']
# %store melanoma_45 >> melanomaresult.csv
# %store melanoma_45val >> melanomavalue.csv

melanoma_46 = sortedmelanoma_46['Token']
melanoma_46val = sortedmelanoma_46['melanoma_46']
# %store melanoma_46 >> melanomaresult.csv
# %store melanoma_46val >> melanomavalue.csv

melanoma_47 = sortedmelanoma_47['Token']
melanoma_47val = sortedmelanoma_47['melanoma_47']
# %store melanoma_47 >> melanomaresult.csv
# %store melanoma_47val >> melanomavalue.csv

melanoma_48 = sortedmelanoma_48['Token']
melanoma_48val = sortedmelanoma_48['melanoma_48']
# %store melanoma_48 >> melanomaresult.csv
# %store melanoma_48val >> melanomavalue.csv

melanoma_49 = sortedmelanoma_49['Token']
melanoma_49val = sortedmelanoma_49['melanoma_49']
# %store melanoma_49 >> melanomaresult.csv
# %store melanoma_49val >> melanomavalue.csv

melanoma_50 = sortedmelanoma_50['Token']
melanoma_50val = sortedmelanoma_50['melanoma_50']
# %store melanoma_50 >> melanomaresult.csv
# %store melanoma_50val >> melanomavalue.csv

melanoma_51 = sortedmelanoma_51['Token']
melanoma_51val = sortedmelanoma_51['melanoma_51']
# %store melanoma_51 >> melanomaresult.csv
# %store melanoma_51val >> melanomavalue.csv

melanoma_52 = sortedmelanoma_52['Token']
melanoma_52val = sortedmelanoma_52['melanoma_52']
# %store melanoma_52 >> melanomaresult.csv
# %store melanoma_52val >> melanomavalue.csv

melanoma_53 = sortedmelanoma_53['Token']
melanoma_53val = sortedmelanoma_53['melanoma_53']
# %store melanoma_53 >> melanomaresult.csv
# %store melanoma_53val >> melanomavalue.csv

melanoma_54 = sortedmelanoma_54['Token']
melanoma_54val = sortedmelanoma_54['melanoma_54']
# %store melanoma_54 >> melanomaresult.csv
# %store melanoma_54val >> melanomavalue.csv

melanoma_55 = sortedmelanoma_55['Token']
melanoma_55val = sortedmelanoma_55['melanoma_55']
# %store melanoma_55 >> melanomaresult.csv
# %store melanoma_55val >> melanomavalue.csv

melanoma_56 = sortedmelanoma_56['Token']
melanoma_56val = sortedmelanoma_56['melanoma_56']
# %store melanoma_56 >> melanomaresult.csv
# %store melanoma_56val >> melanomavalue.csv

melanoma_57 = sortedmelanoma_57['Token']
melanoma_57val = sortedmelanoma_57['melanoma_57']
# %store melanoma_57 >> melanomaresult.csv
# %store melanoma_57val >> melanomavalue.csv

melanoma_58 = sortedmelanoma_58['Token']
melanoma_58val = sortedmelanoma_58['melanoma_58']
# %store melanoma_58 >> melanomaresult.csv
# %store melanoma_58val >> melanomavalue.csv

melanoma_59 = sortedmelanoma_59['Token']
melanoma_59val = sortedmelanoma_59['melanoma_59']
# %store melanoma_59 >> melanomaresult.csv
# %store melanoma_59val >> melanomavalue.csv

melanoma_60 = sortedmelanoma_60['Token']
melanoma_60val = sortedmelanoma_60['melanoma_60']
# %store melanoma_60 >> melanomaresult.csv
# %store melanoma_60val >> melanomavalue.csv

melanoma_61 = sortedmelanoma_61['Token']
melanoma_61val = sortedmelanoma_61['melanoma_61']
# %store melanoma_61 >> melanomaresult.csv
# %store melanoma_61val >> melanomavalue.csv

melanoma_62 = sortedmelanoma_62['Token']
melanoma_62val = sortedmelanoma_62['melanoma_62']
# %store melanoma_62 >> melanomaresult.csv
# %store melanoma_62val >> melanomavalue.csv

melanoma_63 = sortedmelanoma_63['Token']
melanoma_63val = sortedmelanoma_63['melanoma_63']
# %store melanoma_63 >> melanomaresult.csv
# %store melanoma_63val >> melanomavalue.csv

melanoma_64 = sortedmelanoma_64['Token']
melanoma_64val = sortedmelanoma_64['melanoma_64']
# %store melanoma_64 >> melanomaresult.csv
# %store melanoma_64val >> melanomavalue.csv

melanoma_65 = sortedmelanoma_65['Token']
melanoma_65val = sortedmelanoma_65['melanoma_65']
# %store melanoma_65 >> melanomaresult.csv
# %store melanoma_65val >> melanomavalue.csv

melanoma_66 = sortedmelanoma_66['Token']
melanoma_66val = sortedmelanoma_66['melanoma_66']
# %store melanoma_66 >> melanomaresult.csv
# %store melanoma_66val >> melanomavalue.csv

melanoma_67 = sortedmelanoma_67['Token']
melanoma_67val = sortedmelanoma_67['melanoma_67']
# %store melanoma_67 >> melanomaresult.csv
# %store melanoma_67val >> melanomavalue.csv

melanoma_68 = sortedmelanoma_68['Token']
melanoma_68val = sortedmelanoma_68['melanoma_68']
# %store melanoma_68 >> melanomaresult.csv
# %store melanoma_68val >> melanomavalue.csv
# Out:
# Writing 'melanoma_1' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_1val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_2' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_2val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_3' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_3val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_4' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_4val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_5' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_5val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_6' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_6val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_7' (Series) to file 'melanomaresult.csv'.
# Writing 'melanoma_7val' (Series) to file 'melanomavalue.csv'.
# Writing 'melanoma_8' (Series) to file 'melanomaresult.csv'.
# ...

# %%
lungad_1 = sortedlungad_1['Token']
lungad_1val = sortedlungad_1['lungad_1']
# %store lungad_1 >> lungadresult.csv
# %store lungad_1val >> lungadvalue.csv

lungad_2 = sortedlungad_2['Token']
lungad_2val = sortedlungad_2['lungad_2']
# %store lungad_2 >> lungadresult.csv
# %store lungad_2val >> lungadvalue.csv

lungad_3 = sortedlungad_3['Token']
lungad_3val = sortedlungad_3['lungad_3']
# %store lungad_3 >> lungadresult.csv
# %store lungad_3val >> lungadvalue.csv

lungad_4 = sortedlungad_4['Token']
lungad_4val = sortedlungad_4['lungad_4']
# %store lungad_4 >> lungadresult.csv
# %store lungad_4val >> lungadvalue.csv

lungad_5 = sortedlungad_5['Token']
lungad_5val = sortedlungad_5['lungad_5']
# %store lungad_5 >> lungadresult.csv
# %store lungad_5val >> lungadvalue.csv

lungad_6 = sortedlungad_6['Token']
lungad_6val = sortedlungad_6['lungad_6']
# %store lungad_6 >> lungadresult.csv
# %store lungad_6val >> lungadvalue.csv

lungad_7 = sortedlungad_7['Token']
lungad_7val = sortedlungad_7['lungad_7']
# %store lungad_7 >> lungadresult.csv
# %store lungad_7val >> lungadvalue.csv

lungad_8 = sortedlungad_8['Token']
lungad_8val = sortedlungad_8['lungad_8']
# %store lungad_8 >> lungadresult.csv
# %store lungad_8val >> lungadvalue.csv

lungad_9 = sortedlungad_9['Token']
lungad_9val = sortedlungad_9['lungad_9']
# %store lungad_9 >> lungadresult.csv
# %store lungad_9val >> lungadvalue.csv

lungad_10 = sortedlungad_10['Token']
lungad_10val = sortedlungad_10['lungad_10']
# %store lungad_10 >> lungadresult.csv
# %store lungad_10val >> lungadvalue.csv

lungad_11 = sortedlungad_11['Token']
lungad_11val = sortedlungad_11['lungad_11']
# %store lungad_11 >> lungadresult.csv
# %store lungad_11val >> lungadvalue.csv

lungad_12 = sortedlungad_12['Token']
lungad_12val = sortedlungad_12['lungad_12']
# %store lungad_12 >> lungadresult.csv
# %store lungad_12val >> lungadvalue.csv

lungad_13 = sortedlungad_13['Token']
lungad_13val = sortedlungad_13['lungad_13']
# %store lungad_13 >> lungadresult.csv
# %store lungad_13val >> lungadvalue.csv

lungad_14 = sortedlungad_14['Token']
lungad_14val = sortedlungad_14['lungad_14']
# %store lungad_14 >> lungadresult.csv
# %store lungad_14val >> lungadvalue.csv

lungad_15 = sortedlungad_15['Token']
lungad_15val = sortedlungad_15['lungad_15']
# %store lungad_15 >> lungadresult.csv
# %store lungad_15val >> lungadvalue.csv

lungad_16 = sortedlungad_16['Token']
lungad_16val = sortedlungad_16['lungad_16']
# %store lungad_16 >> lungadresult.csv
# %store lungad_16val >> lungadvalue.csv

lungad_17 = sortedlungad_17['Token']
lungad_17val = sortedlungad_17['lungad_17']
# %store lungad_17 >> lungadresult.csv
# %store lungad_17val >> lungadvalue.csv

lungad_18 = sortedlungad_18['Token']
lungad_18val = sortedlungad_18['lungad_18']
# %store lungad_18 >> lungadresult.csv
# %store lungad_18val >> lungadvalue.csv

lungad_19 = sortedlungad_19['Token']
lungad_19val = sortedlungad_19['lungad_19']
# %store lungad_19 >> lungadresult.csv
# %store lungad_19val >> lungadvalue.csv

lungad_20 = sortedlungad_20['Token']
lungad_20val = sortedlungad_20['lungad_20']
# %store lungad_20 >> lungadresult.csv
# %store lungad_20val >> lungadvalue.csv

lungad_21 = sortedlungad_21['Token']
lungad_21val = sortedlungad_21['lungad_21']
# %store lungad_21 >> lungadresult.csv
# %store lungad_21val >> lungadvalue.csv

lungad_22 = sortedlungad_22['Token']
lungad_22val = sortedlungad_22['lungad_22']
# %store lungad_22 >> lungadresult.csv
# %store lungad_22val >> lungadvalue.csv

lungad_23 = sortedlungad_23['Token']
lungad_23val = sortedlungad_23['lungad_23']
# %store lungad_23 >> lungadresult.csv
# %store lungad_23val >> lungadvalue.csv

lungad_24 = sortedlungad_24['Token']
lungad_24val = sortedlungad_24['lungad_24']
# %store lungad_24 >> lungadresult.csv
# %store lungad_24val >> lungadvalue.csv

lungad_25 = sortedlungad_25['Token']
lungad_25val = sortedlungad_25['lungad_25']
# %store lungad_25 >> lungadresult.csv
# %store lungad_25val >> lungadvalue.csv

lungad_26 = sortedlungad_26['Token']
lungad_26val = sortedlungad_26['lungad_26']
# %store lungad_26 >> lungadresult.csv
# %store lungad_26val >> lungadvalue.csv

lungad_27 = sortedlungad_27['Token']
lungad_27val = sortedlungad_27['lungad_27']
# %store lungad_27 >> lungadresult.csv
# %store lungad_27val >> lungadvalue.csv

lungad_28 = sortedlungad_28['Token']
lungad_28val = sortedlungad_28['lungad_28']
# %store lungad_28 >> lungadresult.csv
# %store lungad_28val >> lungadvalue.csv

lungad_29 = sortedlungad_29['Token']
lungad_29val = sortedlungad_29['lungad_29']
# %store lungad_29 >> lungadresult.csv
# %store lungad_29val >> lungadvalue.csv

lungad_30 = sortedlungad_30['Token']
lungad_30val = sortedlungad_30['lungad_30']
# %store lungad_30 >> lungadresult.csv
# %store lungad_30val >> lungadvalue.csv

lungad_31 = sortedlungad_31['Token']
lungad_31val = sortedlungad_31['lungad_31']
# %store lungad_31 >> lungadresult.csv
# %store lungad_31val >> lungadvalue.csv

lungad_32 = sortedlungad_32['Token']
lungad_32val = sortedlungad_32['lungad_32']
# %store lungad_32 >> lungadresult.csv
# %store lungad_32val >> lungadvalue.csv
# Out:
# Writing 'lungad_1' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_1val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_2' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_2val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_3' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_3val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_4' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_4val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_5' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_5val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_6' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_6val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_7' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_7val' (Series) to file 'lungadvalue.csv'.
# Writing 'lungad_8' (Series) to file 'lungadresult.csv'.
# Writing 'lungad_8val' (Series) to file 'lungadvalue.csv'.
# ...

# %%
sortedlungad_1.head(10)
# Out:
#         Token  lungad_1
# 137350    C>A   25513.0
# 1637013   C>A   25513.0
# 1637015   C>T   16704.0
# 137352    C>T   16704.0
# 1637017   T>C   10451.0
# 137354    T>C   10451.0
# 1637016   T>A    9728.0
# 137353    T>A    9728.0
# 1637018   T>G    5838.0
# 137355    T>G    5838.0

# %%
sortedlungad_10.head(10)
# Out:
#         Token  lungad_10
# 137350    C>A    29583.0
# 1637013   C>A    29583.0
# 1637015   C>T    20449.0
# 137352    C>T    20449.0
# 1637017   T>C    13778.0
# 137354    T>C    13778.0
# 1637016   T>A    11098.0
# 137353    T>A    11098.0
# 1637018   T>G     7999.0
# 137355    T>G     7999.0

# %%
sortedlungad_10['Token'].head(10)== sortedlungad_1['Token'].head(10)
# Out:
# 137350    True
# 137352    True
# 137354    True
# 137353    True
# 137355    True
# 137351    True
# 0         True
# 68289     True
# 68290     True
# 137349    True
# Name: Token, dtype: bool

# %%
sortedlungad_12['Token'].head(10) == sortedlungad_10['Token'].head(10)
# Out:
# 137350    True
# 137352    True
# 137354    True
# 137353    True
# 137355    True
# 137351    True
# 0         True
# 68289     True
# 68290     True
# 137349    True
# Name: Token, dtype: bool

# %%
sortedlungad_11['Token'].head(10)
# Out:
# 137352            C>T
# 137350            C>A
# 137354            T>C
# 137355            T>G
# 137353            T>A
# 137351            C>G
# 0         3AAAAAAAAAA
# 68289     3TTTTTTTTTT
# 68290     5AAAAAAAAAA
# 137349    5TTTTTTTTTT
# Name: Token, dtype: object

# %%
sortedlungad_12['Token'].head(10)
# Out:
# 137350            C>A
# 137352            C>T
# 137354            T>C
# 137353            T>A
# 137355            T>G
# 137351            C>G
# 0         3AAAAAAAAAA
# 68289     3TTTTTTTTTT
# 68290     5AAAAAAAAAA
# 137349    5TTTTTTTTTT
# Name: Token, dtype: object

# %%
sortedlungad_12['Token'].head(10).equals(sortedlungad_11['Token'].head(10))
# Out:
# False

# %%
sortedtop10_12 = sortedlungad_12.head(10).merge(sortedlungad_10.head(10),on='Token',
                   how='outer')

# %%
sortedtop10_12
# Out:
#          Token  lungad_12  lungad_10
# 0          C>A    31868.0    29583.0
# 1          C>T    19915.0    20449.0
# 2          T>C    13557.0    13778.0
# 3          T>A    10743.0    11098.0
# 4          T>G     7001.0     7999.0
# 5          C>G     5179.0     5264.0
# 6  3AAAAAAAAAA      827.0     1081.0
# 7  3TTTTTTTTTT      808.0      995.0
# 8  5AAAAAAAAAA      453.0      525.0
# 9  5TTTTTTTTTT      410.0      451.0

# %%
sortedtop1_12 = sortedlungad_12.head(10).merge(sortedlungad_1.head(10),on='Token',
                   how='outer')

# %%
sortedtop1_12
# Out:
#          Token  lungad_12  lungad_1
# 0          C>A    31868.0   25513.0
# 1          C>T    19915.0   16704.0
# 2          T>C    13557.0   10451.0
# 3          T>A    10743.0    9728.0
# 4          T>G     7001.0    5838.0
# 5          C>G     5179.0    3505.0
# 6  3AAAAAAAAAA      827.0    1793.0
# 7  3TTTTTTTTTT      808.0    1609.0
# 8  5AAAAAAAAAA      453.0     904.0
# 9  5TTTTTTTTTT      410.0     811.0

# %%
df = sortedlungad_1.head(10).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_11.head(10), how='left', on=['Token'])

# %%
df
# Out:
#          Token  lungad_1  lungad_12  lungad_11
# 0          C>A   25513.0    31868.0     7185.0
# 1          C>T   16704.0    19915.0     8555.0
# 2          T>C   10451.0    13557.0     5720.0
# 3          T>A    9728.0    10743.0     3425.0
# 4          T>G    5838.0     7001.0     3494.0
# 5          C>G    3505.0     5179.0     2331.0
# 6  3AAAAAAAAAA    1793.0      827.0      607.0
# 7  3TTTTTTTTTT    1609.0      808.0      506.0
# 8  5AAAAAAAAAA     904.0      453.0      299.0
# 9  5TTTTTTTTTT     811.0      410.0      263.0

# %%
df_10
# Out:
#          Token  lungad_1  lungad_12  lungad_11  lungad_10  lungad_13  \
# 0          C>A   25513.0    31868.0     7185.0    29583.0     6412.0
# 1          C>T   16704.0    19915.0     8555.0    20449.0    14734.0
# 2          T>C   10451.0    13557.0     5720.0    13778.0    12597.0
# 3          T>A    9728.0    10743.0     3425.0    11098.0     6238.0
# 4          T>G    5838.0     7001.0     3494.0     7999.0     6216.0
# 5          C>G    3505.0     5179.0     2331.0     5264.0     3096.0
# 6  3AAAAAAAAAA    1793.0      827.0      607.0     1081.0      887.0
# 7  3TTTTTTTTTT    1609.0      808.0      506.0      995.0      683.0
# 8  5AAAAAAAAAA     904.0      453.0      299.0      525.0      398.0
# 9  5TTTTTTTTTT     811.0      410.0      263.0      451.0      356.0
#
#    lungad_14  lungad_15  lungad_16  lungad_17    ...     lungad_41  lungad_42  \
# 0     4826.0    32115.0    20664.0    15809.0    ...       12068.0    13983.0
# ...

# %%
df_100 = sortedlungad_1.head(100).merge(sortedlungad_12.head(100), how='left', on=['Token']).merge(sortedlungad_11.head(100), how='left', on=['Token']).merge(sortedlungad_10.head(100), how='left', on=['Token']).merge(sortedlungad_13.head(100), how='left', on=['Token']).merge(sortedlungad_14.head(100), how='left', on=['Token']).merge(sortedlungad_15.head(100), how='left', on=['Token']).merge(sortedlungad_16.head(100), how='left', on=['Token']).merge(sortedlungad_17.head(100), how='left', on=['Token']).merge(sortedlungad_18.head(100), how='left', on=['Token']).merge(sortedlungad_19.head(100), how='left', on=['Token']).merge(sortedlungad_20.head(100), how='left', on=['Token']).merge(sortedlungad_21.head(100), how='left', on=['Token']).merge(sortedlungad_22.head(100), how='left', on=['Token']).merge(sortedlungad_23.head(100), how='left', on=['Token']).merge(sortedlungad_24.head(100), how='left', on=['Token']).merge(sortedlungad_25.head(100), how='left', on=['Token']).merge(sortedlungad_26.head(100), how='left', on=['Token']).merge(sortedlungad_27.head(100), how='left', on=['Token']).merge(sortedlungad_28.head(100), how='left', on=['Token']).merge(sortedlungad_29.head(100), how='left', on=['Token']).merge(sortedlungad_30.head(100), how='left', on=['Token']).merge(sortedlungad_31.head(100), how='left', on=['Token']).merge(sortedlungad_32.head(100), how='left', on=['Token']).merge(sortedlungad_33.head(100), how='left', on=['Token']).merge(sortedlungad_34.head(100), how='left', on=['Token']).merge(sortedlungad_35.head(100), how='left', on=['Token']).merge(sortedlungad_36.head(100), how='left', on=['Token']).merge(sortedlungad_37.head(100), how='left', on=['Token']).merge(sortedlungad_38.head(100), how='left', on=['Token']).merge(sortedlungad_39.head(100), how='left', on=['Token']).merge(sortedlungad_40.head(100), how='left', on=['Token']).merge(sortedlungad_41.head(100), how='left', on=['Token']).merge(sortedlungad_42.head(100), how='left', on=['Token']).merge(sortedlungad_2.head(100), how='left', on=['Token']).merge(sortedlungad_3.head(100), how='left', on=['Token']).merge(sortedlungad_4.head(100), how='left', on=['Token']).merge(sortedlungad_5.head(100), how='left', on=['Token']).merge(sortedlungad_6.head(100), how='left', on=['Token']).merge(sortedlungad_7.head(100), how='left', on=['Token']).merge(sortedlungad_8.head(100), how='left', on=['Token']).merge(sortedlungad_9.head(100), how='left', on=['Token'])

# %%
df_100
# Out:
#           Token  lungad_1  lungad_12  lungad_11  lungad_10  lungad_13  \
# 0           C>A   25513.0    31868.0     7185.0    29583.0     6412.0
# 1           C>T   16704.0    19915.0     8555.0    20449.0    14734.0
# 2           T>C   10451.0    13557.0     5720.0    13778.0    12597.0
# 3           T>A    9728.0    10743.0     3425.0    11098.0     6238.0
# 4           T>G    5838.0     7001.0     3494.0     7999.0     6216.0
# 5           C>G    3505.0     5179.0     2331.0     5264.0     3096.0
# 6   3AAAAAAAAAA    1793.0      827.0      607.0     1081.0      887.0
# 7   3TTTTTTTTTT    1609.0      808.0      506.0      995.0      683.0
# 8   5AAAAAAAAAA     904.0      453.0      299.0      525.0      398.0
# 9   5TTTTTTTTTT     811.0      410.0      263.0      451.0      356.0
# 10  3TATATATATA     332.0        NaN        NaN        NaN      110.0
# 11  5TATATATATA     302.0        NaN        NaN        NaN      119.0
# ...

# %%
sortedmelanoma_1.head(100)
# Out:
#               Token  melanoma_1
# 137352          C>T     75637.0
# 137354          T>C     11409.0
# 137353          T>A      7507.0
# 137350          C>A      6878.0
# 137355          T>G      6700.0
# 68289   3TTTTTTTTTT      2591.0
# 0       3AAAAAAAAAA      2101.0
# 137351          C>G      2039.0
# 68290   5AAAAAAAAAA      1488.0
# 137349  5TTTTTTTTTT       997.0
# 5602    3ACACACACAC       434.0
# 63080   3TGTGTGTGTG       355.0
# 117209  5GTGTGTGTGT       351.0
# 88479   5CACACACACA       304.0
# 19951   3CACACACACA       217.0
# 67874   3TTTTCTTTTT       212.0
# 134013  5TTCTTTCTTT       209.0
# 121114  5TATATATATA       204.0
# 53741   3TATATATATA       199.0
# 131190  5TGTGTGTGTG       195.0
# 68431   5AAAAAGAAAA       183.0
# 136951  5TTTTCTTTTT       179.0
# 186     3AAAAAGAAAA       173.0
# 49731   3GTGTGTGTGT       173.0
# 99672   5CTCTCTCTCT       170.0
# 83217   5ATATATATAT       164.0
# 9502    3AGAGAGAGAG       163.0
# 1064    3AAAGAAAGAA       162.0
# ...

# %%
mellung
# Out:
#           Token  lungad_1  melanoma_1
# 0           C>A   25513.0      6878.0
# 1           C>T   16704.0     75637.0
# 2           T>C   10451.0     11409.0
# 3           T>A    9728.0      7507.0
# 4           T>G    5838.0      6700.0
# 5           C>G    3505.0      2039.0
# 6   3AAAAAAAAAA    1793.0      2101.0
# 7   3TTTTTTTTTT    1609.0      2591.0
# 8   5AAAAAAAAAA     904.0      1488.0
# 9   5TTTTTTTTTT     811.0       997.0
# 10  3TATATATATA     332.0       199.0
# 11  5TATATATATA     302.0       204.0
# 12  3ACACACACAC     299.0       434.0
# 13  5GTGTGTGTGT     257.0       351.0
# 14  5ATATATATAT     248.0       164.0
# 15  3ATATATATAT     241.0       151.0
# 16  3TGTGTGTGTG     223.0       355.0
# 17  5CACACACACA     218.0       304.0
# 18  3CACACACACA     169.0       217.0
# 19  3AGAGAGAGAG     131.0       163.0
# 20  5TGTGTGTGTG     131.0       195.0
# 21  3GTGTGTGTGT     125.0       173.0
# 22  5CTCTCTCTCT     124.0       170.0
# 23  5TTCTTTCTTT     113.0       209.0
# ...

# %%
df = sortedlungad_1.head(100).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_11, how='left', on=['Token']).merge(sortedlungad_10, how='left', on=['Token']).merge(sortedlungad_13, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_15, how='left', on=['Token']).merge(sortedlungad_16, how='left', on=['Token']).merge(sortedlungad_17, how='left', on=['Token']).merge(sortedlungad_18, how='left', on=['Token']).merge(sortedlungad_19, how='left', on=['Token']).merge(sortedlungad_20, how='left', on=['Token']).merge(sortedlungad_21, how='left', on=['Token']).merge(sortedlungad_22, how='left', on=['Token']).merge(sortedlungad_23, how='left', on=['Token']).merge(sortedlungad_24, how='left', on=['Token']).merge(sortedlungad_25, how='left', on=['Token']).merge(sortedlungad_26, how='left', on=['Token']).merge(sortedlungad_27, how='left', on=['Token']).merge(sortedlungad_28, how='left', on=['Token']).merge(sortedlungad_29, how='left', on=['Token']).merge(sortedlungad_30, how='left', on=['Token']).merge(sortedlungad_31, how='left', on=['Token']).merge(sortedlungad_32, how='left', on=['Token']).merge(sortedlungad_33, how='left', on=['Token']).merge(sortedlungad_34, how='left', on=['Token']).merge(sortedlungad_35, how='left', on=['Token']).merge(sortedlungad_36, how='left', on=['Token']).merge(sortedlungad_37, how='left', on=['Token']).merge(sortedlungad_38, how='left', on=['Token']).merge(sortedlungad_39, how='left', on=['Token']).merge(sortedlungad_40, how='left', on=['Token']).merge(sortedlungad_41, how='left', on=['Token']).merge(sortedlungad_42, how='left', on=['Token']).merge(sortedlungad_2, how='left', on=['Token']).merge(sortedlungad_3, how='left', on=['Token']).merge(sortedlungad_4, how='left', on=['Token']).merge(sortedlungad_5, how='left', on=['Token']).merge(sortedlungad_6, how='left', on=['Token']).merge(sortedlungad_7, how='left', on=['Token']).merge(sortedlungad_8, how='left', on=['Token']).merge(sortedlungad_9, how='left', on=['Token'])

# %%
df
# Out:
#           Token  lungad_1  lungad_12  lungad_11  lungad_10  lungad_13  \
# 0           C>A   25513.0    31868.0     7185.0    29583.0     6412.0
# 1           C>T   16704.0    19915.0     8555.0    20449.0    14734.0
# 2           T>C   10451.0    13557.0     5720.0    13778.0    12597.0
# 3           T>A    9728.0    10743.0     3425.0    11098.0     6238.0
# 4           T>G    5838.0     7001.0     3494.0     7999.0     6216.0
# 5           C>G    3505.0     5179.0     2331.0     5264.0     3096.0
# 6   3AAAAAAAAAA    1793.0      827.0      607.0     1081.0      887.0
# 7   3TTTTTTTTTT    1609.0      808.0      506.0      995.0      683.0
# 8   5AAAAAAAAAA     904.0      453.0      299.0      525.0      398.0
# 9   5TTTTTTTTTT     811.0      410.0      263.0      451.0      356.0
# 10  3TATATATATA     332.0       16.0       11.0       21.0      110.0
# 11  5TATATATATA     302.0       10.0        8.0       20.0      119.0
# ...

# %%
df = sortedmelanoma_1.head(100).merge(sortedmelanoma_12, how='left', on=['Token']).merge(sortedmelanoma_11, how='left', on=['Token']).merge(sortedmelanoma_10, how='left', on=['Token']).merge(sortedmelanoma_13, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_15, how='left', on=['Token']).merge(sortedmelanoma_16, how='left', on=['Token']).merge(sortedmelanoma_17, how='left', on=['Token']).merge(sortedmelanoma_18, how='left', on=['Token']).merge(sortedmelanoma_19, how='left', on=['Token']).merge(sortedmelanoma_20, how='left', on=['Token']).merge(sortedmelanoma_21, how='left', on=['Token']).merge(sortedmelanoma_22, how='left', on=['Token']).merge(sortedmelanoma_23, how='left', on=['Token']).merge(sortedmelanoma_24, how='left', on=['Token']).merge(sortedmelanoma_25, how='left', on=['Token']).merge(sortedmelanoma_26, how='left', on=['Token']).merge(sortedmelanoma_27, how='left', on=['Token']).merge(sortedmelanoma_28, how='left', on=['Token']).merge(sortedmelanoma_29, how='left', on=['Token']).merge(sortedmelanoma_30, how='left', on=['Token']).merge(sortedmelanoma_31, how='left', on=['Token']).merge(sortedmelanoma_32, how='left', on=['Token']).merge(sortedmelanoma_33, how='left', on=['Token']).merge(sortedmelanoma_34, how='left', on=['Token']).merge(sortedmelanoma_35, how='left', on=['Token']).merge(sortedmelanoma_36, how='left', on=['Token']).merge(sortedmelanoma_37, how='left', on=['Token']).merge(sortedmelanoma_38, how='left', on=['Token']).merge(sortedmelanoma_39, how='left', on=['Token']).merge(sortedmelanoma_40, how='left', on=['Token']).merge(sortedmelanoma_41, how='left', on=['Token']).merge(sortedmelanoma_42, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_3, how='left', on=['Token']).merge(sortedmelanoma_4, how='left', on=['Token']).merge(sortedmelanoma_5, how='left', on=['Token']).merge(sortedmelanoma_6, how='left', on=['Token']).merge(sortedmelanoma_7, how='left', on=['Token']).merge(sortedmelanoma_8, how='left', on=['Token']).merge(sortedmelanoma_9, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_3, how='left', on=['Token']).merge(sortedmelanoma_4, how='left', on=['Token']).merge(sortedmelanoma_5, how='left', on=['Token']).merge(sortedmelanoma_6, how='left', on=['Token']).merge(sortedmelanoma_7, how='left', on=['Token']).merge(sortedmelanoma_43, how='left', on=['Token']).merge(sortedmelanoma_44, how='left', on=['Token'])

# %%
df
# Out:
#           Token  melanoma_1  melanoma_12  melanoma_11  melanoma_10  \
# 0           C>T     75637.0      21884.0      57134.0      67126.0
# 1           T>C     11409.0      16285.0      11382.0       8665.0
# 2           T>A      7507.0      12451.0       9011.0       6676.0
# 3           C>A      6878.0      10944.0       5417.0       4101.0
# 4           T>G      6700.0       9677.0       6973.0       4426.0
# 5   3TTTTTTTTTT      2591.0       3527.0       1976.0       1200.0
# 6   3AAAAAAAAAA      2101.0       4762.0       1659.0       1212.0
# 7           C>G      2039.0       3207.0       1714.0       1064.0
# 8   5AAAAAAAAAA      1488.0       2007.0       1095.0        663.0
# 9   5TTTTTTTTTT       997.0       2105.0        785.0        557.0
# 10  3ACACACACAC       434.0        842.0        277.0        269.0
# 11  3TGTGTGTGTG       355.0        620.0        219.0        168.0
# 12  5GTGTGTGTGT       351.0        788.0        268.0        203.0
# ...

# %%
lungad_melanoma1000df = sortedlungad_1.head(1000).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_11, how='left', on=['Token']).merge(sortedlungad_10, how='left', on=['Token']).merge(sortedlungad_13, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_15, how='left', on=['Token']).merge(sortedlungad_16, how='left', on=['Token']).merge(sortedlungad_17, how='left', on=['Token']).merge(sortedlungad_18, how='left', on=['Token']).merge(sortedlungad_19, how='left', on=['Token']).merge(sortedlungad_20, how='left', on=['Token']).merge(sortedlungad_21, how='left', on=['Token']).merge(sortedlungad_22, how='left', on=['Token']).merge(sortedlungad_23, how='left', on=['Token']).merge(sortedlungad_24, how='left', on=['Token']).merge(sortedlungad_25, how='left', on=['Token']).merge(sortedlungad_26, how='left', on=['Token']).merge(sortedlungad_27, how='left', on=['Token']).merge(sortedlungad_28, how='left', on=['Token']).merge(sortedlungad_29, how='left', on=['Token']).merge(sortedlungad_30, how='left', on=['Token']).merge(sortedlungad_31, how='left', on=['Token']).merge(sortedlungad_32, how='left', on=['Token']).merge(sortedlungad_33, how='left', on=['Token']).merge(sortedlungad_34, how='left', on=['Token']).merge(sortedlungad_35, how='left', on=['Token']).merge(sortedlungad_36, how='left', on=['Token']).merge(sortedlungad_37, how='left', on=['Token']).merge(sortedlungad_38, how='left', on=['Token']).merge(sortedlungad_39, how='left', on=['Token']).merge(sortedlungad_40, how='left', on=['Token']).merge(sortedlungad_41, how='left', on=['Token']).merge(sortedlungad_42, how='left', on=['Token']).merge(sortedlungad_2, how='left', on=['Token']).merge(sortedlungad_3, how='left', on=['Token']).merge(sortedlungad_4, how='left', on=['Token']).merge(sortedlungad_5, how='left', on=['Token']).merge(sortedlungad_6, how='left', on=['Token']).merge(sortedlungad_7, how='left', on=['Token']).merge(sortedlungad_8, how='left', on=['Token']).merge(sortedlungad_9, how='left', on=['Token']) .merge(sortedmelanoma_1, how='left', on=['Token']).merge(sortedmelanoma_12, how='left', on=['Token']).merge(sortedmelanoma_11, how='left', on=['Token']).merge(sortedmelanoma_10, how='left', on=['Token']).merge(sortedmelanoma_13, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_15, how='left', on=['Token']).merge(sortedmelanoma_16, how='left', on=['Token']).merge(sortedmelanoma_17, how='left', on=['Token']).merge(sortedmelanoma_18, how='left', on=['Token']).merge(sortedmelanoma_19, how='left', on=['Token']).merge(sortedmelanoma_20, how='left', on=['Token']).merge(sortedmelanoma_21, how='left', on=['Token']).merge(sortedmelanoma_22, how='left', on=['Token']).merge(sortedmelanoma_23, how='left', on=['Token']).merge(sortedmelanoma_24, how='left', on=['Token']).merge(sortedmelanoma_25, how='left', on=['Token']).merge(sortedmelanoma_26, how='left', on=['Token']).merge(sortedmelanoma_27, how='left', on=['Token']).merge(sortedmelanoma_28, how='left', on=['Token']).merge(sortedmelanoma_29, how='left', on=['Token']).merge(sortedmelanoma_30, how='left', on=['Token']).merge(sortedmelanoma_31, how='left', on=['Token']).merge(sortedmelanoma_32, how='left', on=['Token']).merge(sortedmelanoma_33, how='left', on=['Token']).merge(sortedmelanoma_34, how='left', on=['Token']).merge(sortedmelanoma_35, how='left', on=['Token']).merge(sortedmelanoma_36, how='left', on=['Token']).merge(sortedmelanoma_37, how='left', on=['Token']).merge(sortedmelanoma_38, how='left', on=['Token']).merge(sortedmelanoma_39, how='left', on=['Token']).merge(sortedmelanoma_40, how='left', on=['Token']).merge(sortedmelanoma_41, how='left', on=['Token']).merge(sortedmelanoma_42, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_43, how='left', on=['Token']).merge(sortedmelanoma_44, how='left', on=['Token']).merge(sortedmelanoma_45, how='left', on=['Token']).merge(sortedmelanoma_46, how='left', on=['Token']).merge(sortedmelanoma_47, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_50, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_51, how='left', on=['Token']).merge(sortedmelanoma_52, how='left', on=['Token']).merge(sortedmelanoma_53, how='left', on=['Token']).merge(sortedmelanoma_54, how='left', on=['Token']).merge(sortedmelanoma_55, how='left', on=['Token']).merge(sortedmelanoma_56, how='left', on=['Token']).merge(sortedmelanoma_57, how='left', on=['Token']).merge(sortedmelanoma_59, how='left', on=['Token']).merge(sortedmelanoma_60, how='left', on=['Token']).merge(sortedmelanoma_61, how='left', on=['Token']).merge(sortedmelanoma_62, how='left', on=['Token']).merge(sortedmelanoma_63, how='left', on=['Token']).merge(sortedmelanoma_64, how='left', on=['Token']).merge(sortedmelanoma_65, how='left', on=['Token']).merge(sortedmelanoma_66, how='left', on=['Token']).merge(sortedmelanoma_67, how='left', on=['Token']).merge(sortedmelanoma_68, how='left', on=['Token'])

# %%
lungad_melanoma1000df
# Out:
#            Token  lungad_1  lungad_12  lungad_11  lungad_10  lungad_13  \
# 0            C>A   25513.0    31868.0     7185.0    29583.0     6412.0
# 1            C>T   16704.0    19915.0     8555.0    20449.0    14734.0
# 2            T>C   10451.0    13557.0     5720.0    13778.0    12597.0
# 3            T>A    9728.0    10743.0     3425.0    11098.0     6238.0
# 4            T>G    5838.0     7001.0     3494.0     7999.0     6216.0
# 5            C>G    3505.0     5179.0     2331.0     5264.0     3096.0
# 6    3AAAAAAAAAA    1793.0      827.0      607.0     1081.0      887.0
# 7    3TTTTTTTTTT    1609.0      808.0      506.0      995.0      683.0
# 8    5AAAAAAAAAA     904.0      453.0      299.0      525.0      398.0
# 9    5TTTTTTTTTT     811.0      410.0      263.0      451.0      356.0
# 10   3TATATATATA     332.0       16.0       11.0       21.0      110.0
# 11   5TATATATATA     302.0       10.0        8.0       20.0      119.0
# ...

# %%
df = sortedlungad_1.head(100).merge(sortedlungad_11, how='left', on=['Token']).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_13, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_15, how='left', on=['Token']).merge(sortedlungad_16, how='left', on=['Token']).merge(sortedlungad_17, how='left', on=['Token']).merge(sortedlungad_18, how='left', on=['Token']).merge(sortedlungad_19, how='left', on=['Token']).merge(sortedlungad_3, how='left', on=['Token']).merge(sortedlungad_2, how='left', on=['Token']).merge(sortedlungad_4, how='left', on=['Token']).merge(sortedlungad_5, how='left', on=['Token']).merge(sortedlungad_6, how='left', on=['Token']).merge(sortedlungad_20, how='left', on=['Token']).merge(sortedlungad_7, how='left', on=['Token']).merge(sortedlungad_8, how='left', on=['Token']).merge(sortedlungad_9, how='left', on=['Token']).merge(sortedlungad_10, how='left', on=['Token']).merge(sortedlungad_21, how='left', on=['Token']).merge(sortedlungad_22, how='left', on=['Token']).merge(sortedlungad_23, how='left', on=['Token']).merge(sortedlungad_24, how='left', on=['Token']).merge(sortedlungad_25, how='left', on=['Token']).merge(sortedlungad_26, how='left', on=['Token']).merge(sortedlungad_27, how='left', on=['Token']).merge(sortedlungad_28, how='left', on=['Token']).merge(sortedlungad_29, how='left', on=['Token']).merge(sortedlungad_30, how='left', on=['Token']).merge(sortedlungad_31, how='left', on=['Token']).merge(sortedlungad_32, how='left', on=['Token']).merge(sortedlungad_33, how='left', on=['Token']).merge(sortedlungad_34, how='left', on=['Token']).merge(sortedlungad_35, how='left', on=['Token']).merge(sortedlungad_36, how='left', on=['Token']).merge(sortedlungad_37, how='left', on=['Token']).merge(sortedlungad_38, how='left', on=['Token']).merge(sortedlungad_39, how='left', on=['Token']).merge(sortedlungad_40, how='left', on=['Token']).merge(sortedlungad_41, how='left', on=['Token']).merge(sortedlungad_42, how='left', on=['Token']) .merge(sortedmelanoma_11, how='left', on=['Token']).merge(sortedmelanoma_12, how='left', on=['Token']).merge(sortedmelanoma_13, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_15, how='left', on=['Token']).merge(sortedmelanoma_1, how='left', on=['Token']).merge(sortedmelanoma_16, how='left', on=['Token']).merge(sortedmelanoma_17, how='left', on=['Token']).merge(sortedmelanoma_18, how='left', on=['Token']).merge(sortedmelanoma_19, how='left', on=['Token']).merge(sortedmelanoma_3, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_4, how='left', on=['Token']).merge(sortedmelanoma_5, how='left', on=['Token']).merge(sortedmelanoma_6, how='left', on=['Token']).merge(sortedmelanoma_20, how='left', on=['Token']).merge(sortedmelanoma_7, how='left', on=['Token']).merge(sortedmelanoma_8, how='left', on=['Token']).merge(sortedmelanoma_9, how='left', on=['Token']).merge(sortedmelanoma_10, how='left', on=['Token']).merge(sortedmelanoma_21, how='left', on=['Token']).merge(sortedmelanoma_22, how='left', on=['Token']).merge(sortedmelanoma_23, how='left', on=['Token']).merge(sortedmelanoma_24, how='left', on=['Token']).merge(sortedmelanoma_25, how='left', on=['Token']).merge(sortedmelanoma_26, how='left', on=['Token']).merge(sortedmelanoma_27, how='left', on=['Token']).merge(sortedmelanoma_28, how='left', on=['Token']).merge(sortedmelanoma_29, how='left', on=['Token']).merge(sortedmelanoma_30, how='left', on=['Token']).merge(sortedmelanoma_31, how='left', on=['Token']).merge(sortedmelanoma_32, how='left', on=['Token']).merge(sortedmelanoma_33, how='left', on=['Token']).merge(sortedmelanoma_34, how='left', on=['Token']).merge(sortedmelanoma_35, how='left', on=['Token']).merge(sortedmelanoma_36, how='left', on=['Token']).merge(sortedmelanoma_37, how='left', on=['Token']).merge(sortedmelanoma_38, how='left', on=['Token']).merge(sortedmelanoma_39, how='left', on=['Token']).merge(sortedmelanoma_40, how='left', on=['Token']).merge(sortedmelanoma_41, how='left', on=['Token']).merge(sortedmelanoma_42, how='left', on=['Token']).merge(sortedmelanoma_43, how='left', on=['Token']).merge(sortedmelanoma_44, how='left', on=['Token']).merge(sortedmelanoma_45, how='left', on=['Token']).merge(sortedmelanoma_46, how='left', on=['Token']).merge(sortedmelanoma_47, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_50, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_51, how='left', on=['Token']).merge(sortedmelanoma_52, how='left', on=['Token']).merge(sortedmelanoma_53, how='left', on=['Token']).merge(sortedmelanoma_54, how='left', on=['Token']).merge(sortedmelanoma_55, how='left', on=['Token']).merge(sortedmelanoma_56, how='left', on=['Token']).merge(sortedmelanoma_57, how='left', on=['Token']).merge(sortedmelanoma_59, how='left', on=['Token']).merge(sortedmelanoma_60, how='left', on=['Token']).merge(sortedmelanoma_61, how='left', on=['Token']).merge(sortedmelanoma_62, how='left', on=['Token']).merge(sortedmelanoma_63, how='left', on=['Token']).merge(sortedmelanoma_64, how='left', on=['Token']).merge(sortedmelanoma_65, how='left', on=['Token']).merge(sortedmelanoma_66, how='left', on=['Token']).merge(sortedmelanoma_67, how='left', on=['Token']).merge(sortedmelanoma_68, how='left', on=['Token'])

# %%
# %store df >> top100LungMel.csv
# Out:
# Writing 'df' (DataFrame) to file 'top100LungMel.csv'.

# %%
df1000 = sortedlungad_1.head(1000).merge(sortedlungad_11, how='left', on=['Token']).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_13, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_15, how='left', on=['Token']).merge(sortedlungad_16, how='left', on=['Token']).merge(sortedlungad_17, how='left', on=['Token']).merge(sortedlungad_18, how='left', on=['Token']).merge(sortedlungad_19, how='left', on=['Token']).merge(sortedlungad_3, how='left', on=['Token']).merge(sortedlungad_2, how='left', on=['Token']).merge(sortedlungad_4, how='left', on=['Token']).merge(sortedlungad_5, how='left', on=['Token']).merge(sortedlungad_6, how='left', on=['Token']).merge(sortedlungad_20, how='left', on=['Token']).merge(sortedlungad_7, how='left', on=['Token']).merge(sortedlungad_8, how='left', on=['Token']).merge(sortedlungad_9, how='left', on=['Token']).merge(sortedlungad_10, how='left', on=['Token']).merge(sortedlungad_21, how='left', on=['Token']).merge(sortedlungad_22, how='left', on=['Token']).merge(sortedlungad_23, how='left', on=['Token']).merge(sortedlungad_24, how='left', on=['Token']).merge(sortedlungad_25, how='left', on=['Token']).merge(sortedlungad_26, how='left', on=['Token']).merge(sortedlungad_27, how='left', on=['Token']).merge(sortedlungad_28, how='left', on=['Token']).merge(sortedlungad_29, how='left', on=['Token']).merge(sortedlungad_30, how='left', on=['Token']).merge(sortedlungad_31, how='left', on=['Token']).merge(sortedlungad_32, how='left', on=['Token']).merge(sortedlungad_33, how='left', on=['Token']).merge(sortedlungad_34, how='left', on=['Token']).merge(sortedlungad_35, how='left', on=['Token']).merge(sortedlungad_36, how='left', on=['Token']).merge(sortedlungad_37, how='left', on=['Token']).merge(sortedlungad_38, how='left', on=['Token']).merge(sortedlungad_39, how='left', on=['Token']).merge(sortedlungad_40, how='left', on=['Token']).merge(sortedlungad_41, how='left', on=['Token']).merge(sortedlungad_42, how='left', on=['Token']) .merge(sortedmelanoma_11, how='left', on=['Token']).merge(sortedmelanoma_12, how='left', on=['Token']).merge(sortedmelanoma_13, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_15, how='left', on=['Token']).merge(sortedmelanoma_1, how='left', on=['Token']).merge(sortedmelanoma_16, how='left', on=['Token']).merge(sortedmelanoma_17, how='left', on=['Token']).merge(sortedmelanoma_18, how='left', on=['Token']).merge(sortedmelanoma_19, how='left', on=['Token']).merge(sortedmelanoma_3, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_4, how='left', on=['Token']).merge(sortedmelanoma_5, how='left', on=['Token']).merge(sortedmelanoma_6, how='left', on=['Token']).merge(sortedmelanoma_20, how='left', on=['Token']).merge(sortedmelanoma_7, how='left', on=['Token']).merge(sortedmelanoma_8, how='left', on=['Token']).merge(sortedmelanoma_9, how='left', on=['Token']).merge(sortedmelanoma_10, how='left', on=['Token']).merge(sortedmelanoma_21, how='left', on=['Token']).merge(sortedmelanoma_22, how='left', on=['Token']).merge(sortedmelanoma_23, how='left', on=['Token']).merge(sortedmelanoma_24, how='left', on=['Token']).merge(sortedmelanoma_25, how='left', on=['Token']).merge(sortedmelanoma_26, how='left', on=['Token']).merge(sortedmelanoma_27, how='left', on=['Token']).merge(sortedmelanoma_28, how='left', on=['Token']).merge(sortedmelanoma_29, how='left', on=['Token']).merge(sortedmelanoma_30, how='left', on=['Token']).merge(sortedmelanoma_31, how='left', on=['Token']).merge(sortedmelanoma_32, how='left', on=['Token']).merge(sortedmelanoma_33, how='left', on=['Token']).merge(sortedmelanoma_34, how='left', on=['Token']).merge(sortedmelanoma_35, how='left', on=['Token']).merge(sortedmelanoma_36, how='left', on=['Token']).merge(sortedmelanoma_37, how='left', on=['Token']).merge(sortedmelanoma_38, how='left', on=['Token']).merge(sortedmelanoma_39, how='left', on=['Token']).merge(sortedmelanoma_40, how='left', on=['Token']).merge(sortedmelanoma_41, how='left', on=['Token']).merge(sortedmelanoma_42, how='left', on=['Token']).merge(sortedmelanoma_43, how='left', on=['Token']).merge(sortedmelanoma_44, how='left', on=['Token']).merge(sortedmelanoma_45, how='left', on=['Token']).merge(sortedmelanoma_46, how='left', on=['Token']).merge(sortedmelanoma_47, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_50, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_51, how='left', on=['Token']).merge(sortedmelanoma_52, how='left', on=['Token']).merge(sortedmelanoma_53, how='left', on=['Token']).merge(sortedmelanoma_54, how='left', on=['Token']).merge(sortedmelanoma_55, how='left', on=['Token']).merge(sortedmelanoma_56, how='left', on=['Token']).merge(sortedmelanoma_57, how='left', on=['Token']).merge(sortedmelanoma_59, how='left', on=['Token']).merge(sortedmelanoma_60, how='left', on=['Token']).merge(sortedmelanoma_61, how='left', on=['Token']).merge(sortedmelanoma_62, how='left', on=['Token']).merge(sortedmelanoma_63, how='left', on=['Token']).merge(sortedmelanoma_64, how='left', on=['Token']).merge(sortedmelanoma_65, how='left', on=['Token']).merge(sortedmelanoma_66, how='left', on=['Token']).merge(sortedmelanoma_67, how='left', on=['Token']).merge(sortedmelanoma_68, how='left', on=['Token'])

# %%
# %store df1000 >> top1000LungMel.csv
# Out:
# Writing 'df1000' (DataFrame) to file 'top1000LungMel.csv'.

# %%
df10 = sortedlungad_1.head(1000).merge(sortedlungad_11, how='left', on=['Token']).merge(sortedlungad_12, how='left', on=['Token']).merge(sortedlungad_13, how='left', on=['Token']).merge(sortedlungad_14, how='left', on=['Token']).merge(sortedlungad_15, how='left', on=['Token']).merge(sortedlungad_16, how='left', on=['Token']).merge(sortedlungad_17, how='left', on=['Token']).merge(sortedlungad_18, how='left', on=['Token']).merge(sortedlungad_19, how='left', on=['Token']).merge(sortedlungad_3, how='left', on=['Token']).merge(sortedlungad_2, how='left', on=['Token']).merge(sortedlungad_4, how='left', on=['Token']).merge(sortedlungad_5, how='left', on=['Token']).merge(sortedlungad_6, how='left', on=['Token']).merge(sortedlungad_20, how='left', on=['Token']).merge(sortedlungad_7, how='left', on=['Token']).merge(sortedlungad_8, how='left', on=['Token']).merge(sortedlungad_9, how='left', on=['Token']).merge(sortedlungad_10, how='left', on=['Token']).merge(sortedlungad_21, how='left', on=['Token']).merge(sortedlungad_22, how='left', on=['Token']).merge(sortedlungad_23, how='left', on=['Token']).merge(sortedlungad_24, how='left', on=['Token']).merge(sortedlungad_25, how='left', on=['Token']).merge(sortedlungad_26, how='left', on=['Token']).merge(sortedlungad_27, how='left', on=['Token']).merge(sortedlungad_28, how='left', on=['Token']).merge(sortedlungad_29, how='left', on=['Token']).merge(sortedlungad_30, how='left', on=['Token']).merge(sortedlungad_31, how='left', on=['Token']).merge(sortedlungad_32, how='left', on=['Token']).merge(sortedlungad_33, how='left', on=['Token']).merge(sortedlungad_34, how='left', on=['Token']).merge(sortedlungad_35, how='left', on=['Token']).merge(sortedlungad_36, how='left', on=['Token']).merge(sortedlungad_37, how='left', on=['Token']).merge(sortedlungad_38, how='left', on=['Token']).merge(sortedlungad_39, how='left', on=['Token']).merge(sortedlungad_40, how='left', on=['Token']).merge(sortedlungad_41, how='left', on=['Token']).merge(sortedlungad_42, how='left', on=['Token']) .merge(sortedmelanoma_11, how='left', on=['Token']).merge(sortedmelanoma_12, how='left', on=['Token']).merge(sortedmelanoma_13, how='left', on=['Token']).merge(sortedmelanoma_14, how='left', on=['Token']).merge(sortedmelanoma_15, how='left', on=['Token']).merge(sortedmelanoma_1, how='left', on=['Token']).merge(sortedmelanoma_16, how='left', on=['Token']).merge(sortedmelanoma_17, how='left', on=['Token']).merge(sortedmelanoma_18, how='left', on=['Token']).merge(sortedmelanoma_19, how='left', on=['Token']).merge(sortedmelanoma_3, how='left', on=['Token']).merge(sortedmelanoma_2, how='left', on=['Token']).merge(sortedmelanoma_4, how='left', on=['Token']).merge(sortedmelanoma_5, how='left', on=['Token']).merge(sortedmelanoma_6, how='left', on=['Token']).merge(sortedmelanoma_20, how='left', on=['Token']).merge(sortedmelanoma_7, how='left', on=['Token']).merge(sortedmelanoma_8, how='left', on=['Token']).merge(sortedmelanoma_9, how='left', on=['Token']).merge(sortedmelanoma_10, how='left', on=['Token']).merge(sortedmelanoma_21, how='left', on=['Token']).merge(sortedmelanoma_22, how='left', on=['Token']).merge(sortedmelanoma_23, how='left', on=['Token']).merge(sortedmelanoma_24, how='left', on=['Token']).merge(sortedmelanoma_25, how='left', on=['Token']).merge(sortedmelanoma_26, how='left', on=['Token']).merge(sortedmelanoma_27, how='left', on=['Token']).merge(sortedmelanoma_28, how='left', on=['Token']).merge(sortedmelanoma_29, how='left', on=['Token']).merge(sortedmelanoma_30, how='left', on=['Token']).merge(sortedmelanoma_31, how='left', on=['Token']).merge(sortedmelanoma_32, how='left', on=['Token']).merge(sortedmelanoma_33, how='left', on=['Token']).merge(sortedmelanoma_34, how='left', on=['Token']).merge(sortedmelanoma_35, how='left', on=['Token']).merge(sortedmelanoma_36, how='left', on=['Token']).merge(sortedmelanoma_37, how='left', on=['Token']).merge(sortedmelanoma_38, how='left', on=['Token']).merge(sortedmelanoma_39, how='left', on=['Token']).merge(sortedmelanoma_40, how='left', on=['Token']).merge(sortedmelanoma_41, how='left', on=['Token']).merge(sortedmelanoma_42, how='left', on=['Token']).merge(sortedmelanoma_43, how='left', on=['Token']).merge(sortedmelanoma_44, how='left', on=['Token']).merge(sortedmelanoma_45, how='left', on=['Token']).merge(sortedmelanoma_46, how='left', on=['Token']).merge(sortedmelanoma_47, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_50, how='left', on=['Token']).merge(sortedmelanoma_49, how='left', on=['Token']).merge(sortedmelanoma_48, how='left', on=['Token']).merge(sortedmelanoma_51, how='left', on=['Token']).merge(sortedmelanoma_52, how='left', on=['Token']).merge(sortedmelanoma_53, how='left', on=['Token']).merge(sortedmelanoma_54, how='left', on=['Token']).merge(sortedmelanoma_55, how='left', on=['Token']).merge(sortedmelanoma_56, how='left', on=['Token']).merge(sortedmelanoma_57, how='left', on=['Token']).merge(sortedmelanoma_59, how='left', on=['Token']).merge(sortedmelanoma_60, how='left', on=['Token']).merge(sortedmelanoma_61, how='left', on=['Token']).merge(sortedmelanoma_62, how='left', on=['Token']).merge(sortedmelanoma_63, how='left', on=['Token']).merge(sortedmelanoma_64, how='left', on=['Token']).merge(sortedmelanoma_65, how='left', on=['Token']).merge(sortedmelanoma_66, how='left', on=['Token']).merge(sortedmelanoma_67, how='left', on=['Token']).merge(sortedmelanoma_68, how='left', on=['Token'])

# %%
# %store df10 >> top10LungMel.csv
# Out:
# Writing 'df10' (DataFrame) to file 'top10LungMel.csv'.

# %%
t= ['a', 'b','c']
v= [1,2,3]
df = pd.DataFrame(np.column_stack([t, v]), columns= ['A','B'])
u = ['a', 'b' ,'d']
v2 =[3,4,5]
df2 = pd.DataFrame(np.column_stack([u, v2]),columns=['A','B'])

# %%
df
# Out:
#    A  B
# 0  a  1
# 1  b  2
# 2  c  3

# %%
df2
# Out:
#    A  B
# 0  a  3
# 1  b  4
# 2  d  5

# %%
merged_inner = pd.merge(df,df2, on=['A'], how='inner')

# %%
merged_inner
# Out:
#    A B_x B_y
# 0  a   1   3
# 1  b   2   4

# %%
pd.merge(sortedlungad_1.head(10), sortedmelanoma_1.head(10), on= ['Token'], how='inner')
# Out:
#          Token  lungad_1  melanoma_1
# 0          C>A   25513.0      6878.0
# 1          C>T   16704.0     75637.0
# 2          T>C   10451.0     11409.0
# 3          T>A    9728.0      7507.0
# 4          T>G    5838.0      6700.0
# 5          C>G    3505.0      2039.0
# 6  3AAAAAAAAAA    1793.0      2101.0
# 7  3TTTTTTTTTT    1609.0      2591.0
# 8  5AAAAAAAAAA     904.0      1488.0
# 9  5TTTTTTTTTT     811.0       997.0

# %%
pd.merge(sortedlungad_1.head(100), sortedmelanoma_1.head(100), on= ['Token'], how='inner')
# Out:
#           Token  lungad_1  melanoma_1
# 0           C>A   25513.0      6878.0
# 1           C>T   16704.0     75637.0
# 2           T>C   10451.0     11409.0
# 3           T>A    9728.0      7507.0
# 4           T>G    5838.0      6700.0
# 5           C>G    3505.0      2039.0
# 6   3AAAAAAAAAA    1793.0      2101.0
# 7   3TTTTTTTTTT    1609.0      2591.0
# 8   5AAAAAAAAAA     904.0      1488.0
# 9   5TTTTTTTTTT     811.0       997.0
# 10  3TATATATATA     332.0       199.0
# 11  5TATATATATA     302.0       204.0
# 12  3ACACACACAC     299.0       434.0
# 13  5GTGTGTGTGT     257.0       351.0
# 14  5ATATATATAT     248.0       164.0
# 15  3ATATATATAT     241.0       151.0
# 16  3TGTGTGTGTG     223.0       355.0
# 17  5CACACACACA     218.0       304.0
# 18  3CACACACACA     169.0       217.0
# 19  3AGAGAGAGAG     131.0       163.0
# 20  5TGTGTGTGTG     131.0       195.0
# 21  3GTGTGTGTGT     125.0       173.0
# 22  5CTCTCTCTCT     124.0       170.0
# 23  5TTCTTTCTTT     113.0       209.0
# ...

# %%
pd.merge(sortedlungad_1.head(1000), sortedmelanoma_1.head(1000), on= ['Token'], how='inner')
# Out:
#            Token  lungad_1  melanoma_1
# 0            C>A   25513.0      6878.0
# 1            C>T   16704.0     75637.0
# 2            T>C   10451.0     11409.0
# 3            T>A    9728.0      7507.0
# 4            T>G    5838.0      6700.0
# 5            C>G    3505.0      2039.0
# 6    3AAAAAAAAAA    1793.0      2101.0
# 7    3TTTTTTTTTT    1609.0      2591.0
# 8    5AAAAAAAAAA     904.0      1488.0
# 9    5TTTTTTTTTT     811.0       997.0
# 10   3TATATATATA     332.0       199.0
# 11   5TATATATATA     302.0       204.0
# 12   3ACACACACAC     299.0       434.0
# 13   5GTGTGTGTGT     257.0       351.0
# 14   5ATATATATAT     248.0       164.0
# 15   3ATATATATAT     241.0       151.0
# 16   3TGTGTGTGTG     223.0       355.0
# 17   5CACACACACA     218.0       304.0
# 18   3CACACACACA     169.0       217.0
# 19   3AGAGAGAGAG     131.0       163.0
# 20   5TGTGTGTGTG     131.0       195.0
# 21   3GTGTGTGTGT     125.0       173.0
# 22   5CTCTCTCTCT     124.0       170.0
# ...

# %%
sortedlungad_1.head(100).merge(sortedlungad_11.head(100), how='inner',on=['Token'])
# Out:
#           Token  lungad_1  lungad_11
# 0           C>A   25513.0     7185.0
# 1           C>T   16704.0     8555.0
# 2           T>C   10451.0     5720.0
# 3           T>A    9728.0     3425.0
# 4           T>G    5838.0     3494.0
# 5           C>G    3505.0     2331.0
# 6   3AAAAAAAAAA    1793.0      607.0
# 7   3TTTTTTTTTT    1609.0      506.0
# 8   5AAAAAAAAAA     904.0      299.0
# 9   5TTTTTTTTTT     811.0      263.0
# 10  3ACACACACAC     299.0      135.0
# 11  5GTGTGTGTGT     257.0      139.0
# 12  3TGTGTGTGTG     223.0      144.0
# 13  5CACACACACA     218.0      134.0
# 14  3CACACACACA     169.0      120.0
# 15  3AGAGAGAGAG     131.0       43.0
# 16  5TGTGTGTGTG     131.0      108.0
# 17  3GTGTGTGTGT     125.0       73.0
# 18  5CTCTCTCTCT     124.0       60.0
# 19  5TTCTTTCTTT     113.0       36.0
# 20  5TTTTCTTTTT     103.0       25.0
# 21  3AAAGAAAGAA      94.0       49.0
# 22  5ACACACACAC      90.0       63.0
# 23  3GAGAGAGAGA      86.0       67.0
# ...

# %%
df = sortedlungad_1.head(100).merge(sortedlungad_11, how='inner', on=['Token']).merge(sortedlungad_12, how='inner', on=['Token']).merge(sortedlungad_13, how='inner', on=['Token']).merge(sortedlungad_14, how='inner', on=['Token']).merge(sortedlungad_15, how='inner', on=['Token']).merge(sortedlungad_16, how='inner', on=['Token']).merge(sortedlungad_17, how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19, how='inner', on=['Token']).merge(sortedlungad_3, how='inner', on=['Token']).merge(sortedlungad_2, how='inner', on=['Token']).merge(sortedlungad_4, how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6, how='inner', on=['Token']).merge(sortedlungad_20, how='inner', on=['Token']).merge(sortedlungad_7, how='inner', on=['Token']).merge(sortedlungad_8, how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10, how='inner', on=['Token']).merge(sortedlungad_21, how='inner', on=['Token']).merge(sortedlungad_22, how='inner', on=['Token']).merge(sortedlungad_23, how='inner', on=['Token']).merge(sortedlungad_24, how='inner', on=['Token']).merge(sortedlungad_25, how='inner', on=['Token']).merge(sortedlungad_26, how='inner', on=['Token']).merge(sortedlungad_27, how='inner', on=['Token']).merge(sortedlungad_28, how='inner', on=['Token']).merge(sortedlungad_29, how='inner', on=['Token']).merge(sortedlungad_30, how='inner', on=['Token']).merge(sortedlungad_31, how='inner', on=['Token']).merge(sortedlungad_32, how='inner', on=['Token']).merge(sortedlungad_33, how='inner', on=['Token']).merge(sortedlungad_34, how='inner', on=['Token']).merge(sortedlungad_35, how='inner', on=['Token']).merge(sortedlungad_36, how='inner', on=['Token']).merge(sortedlungad_37, how='inner', on=['Token']).merge(sortedlungad_38, how='inner', on=['Token']).merge(sortedlungad_39, how='inner', on=['Token']).merge(sortedlungad_40, how='inner', on=['Token']).merge(sortedlungad_41, how='inner', on=['Token']).merge(sortedlungad_42, how='inner', on=['Token'])

# %%
df
# Out:
#           Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0           C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1           C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2           T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3           T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4           T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5           C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6   3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7   3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8   5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9   5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10  3TATATATATA     332.0       11.0       16.0      110.0      165.0
# 11  5TATATATATA     302.0        8.0       10.0      119.0      170.0
# ...

# %%
df = sortedlungad_1.head(100).merge(sortedlungad_11.head(100), how='inner', on=['Token']).merge(sortedlungad_12.head(100), how='inner', on=['Token']).merge(sortedlungad_13.head(100), how='inner', on=['Token']).merge(sortedlungad_14.head(100), how='inner', on=['Token'])

# %%
df
# Out:
#           Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14
# 0           C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1           C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2           T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3           T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4           T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5           C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6   3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7   3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8   5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9   5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10  3ACACACACAC     299.0      135.0      216.0      297.0      161.0
# 11  5GTGTGTGTGT     257.0      139.0      192.0      301.0      184.0
# ...

# %%
df = sortedlungad_1.head(100).merge(sortedlungad_11.head(100), how='inner', on=['Token']).merge(sortedlungad_12.head(100), how='inner', on=['Token']).merge(sortedlungad_13.head(100), how='inner', on=['Token']).merge(sortedlungad_14.head(100), how='inner', on=['Token']).merge(sortedlungad_15.head(100), how='inner', on=['Token']).merge(sortedlungad_16.head(100), how='inner', on=['Token']).merge(sortedlungad_17.head(100), how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19.head(100), how='inner', on=['Token']).merge(sortedlungad_3.head(100), how='inner', on=['Token']).merge(sortedlungad_2.head(100), how='inner', on=['Token']).merge(sortedlungad_4.head(100), how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6.head(100), how='inner', on=['Token']).merge(sortedlungad_20.head(100), how='inner', on=['Token']).merge(sortedlungad_7.head(100), how='inner', on=['Token']).merge(sortedlungad_8.head(100), how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10.head(100), how='inner', on=['Token']).merge(sortedlungad_21.head(100), how='inner', on=['Token']).merge(sortedlungad_22.head(100), how='inner', on=['Token']).merge(sortedlungad_23.head(100), how='inner', on=['Token']).merge(sortedlungad_24.head(100), how='inner', on=['Token']).merge(sortedlungad_25.head(100), how='inner', on=['Token']).merge(sortedlungad_26.head(100), how='inner', on=['Token']).merge(sortedlungad_27.head(100), how='inner', on=['Token'])

# %%
df
# Out:
#           Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0           C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1           C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2           T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3           T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4           T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5           C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6   3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7   3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8   5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9   5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10  3ACACACACAC     299.0      135.0      216.0      297.0      161.0
# 11  5GTGTGTGTGT     257.0      139.0      192.0      301.0      184.0
# ...

# %%
top100df = sortedlungad_1.head(100).merge(sortedlungad_11.head(100), how='inner', on=['Token']).merge(sortedlungad_12.head(100), how='inner', on=['Token']).merge(sortedlungad_13.head(100), how='inner', on=['Token']).merge(sortedlungad_14.head(100), how='inner', on=['Token']).merge(sortedlungad_15.head(100), how='inner', on=['Token']).merge(sortedlungad_16.head(100), how='inner', on=['Token']).merge(sortedlungad_17.head(100), how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19.head(100), how='inner', on=['Token']).merge(sortedlungad_3.head(100), how='inner', on=['Token']).merge(sortedlungad_2.head(100), how='inner', on=['Token']).merge(sortedlungad_4.head(100), how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6.head(100), how='inner', on=['Token']).merge(sortedlungad_20.head(100), how='inner', on=['Token']).merge(sortedlungad_7.head(100), how='inner', on=['Token']).merge(sortedlungad_8.head(100), how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10.head(100), how='inner', on=['Token']).merge(sortedlungad_21.head(100), how='inner', on=['Token']).merge(sortedlungad_22.head(100), how='inner', on=['Token']).merge(sortedlungad_23.head(100), how='inner', on=['Token']).merge(sortedlungad_24.head(100), how='inner', on=['Token']).merge(sortedlungad_25.head(100), how='inner', on=['Token']).merge(sortedlungad_26.head(100), how='inner', on=['Token']).merge(sortedlungad_27.head(100), how='inner', on=['Token']).merge(sortedlungad_28.head(100), how='inner', on=['Token']).merge(sortedlungad_29.head(100), how='inner', on=['Token']).merge(sortedlungad_30.head(100), how='inner', on=['Token']).merge(sortedlungad_31.head(100), how='inner', on=['Token']).merge(sortedlungad_32, how='inner', on=['Token']).merge(sortedlungad_33.head(100), how='inner', on=['Token']).merge(sortedlungad_34.head(100), how='inner', on=['Token']).merge(sortedlungad_35.head(100), how='inner', on=['Token']).merge(sortedlungad_36.head(100), how='inner', on=['Token']).merge(sortedlungad_37.head(100), how='inner', on=['Token']).merge(sortedlungad_38.head(100), how='inner', on=['Token']).merge(sortedlungad_39.head(100), how='inner', on=['Token']).merge(sortedlungad_40.head(100), how='inner', on=['Token']).merge(sortedlungad_41.head(100), how='inner', on=['Token']).merge(sortedlungad_42, how='inner', on=['Token']) .merge(sortedmelanoma_11.head(100), how='inner', on=['Token']).merge(sortedmelanoma_12.head(100), how='inner', on=['Token']).merge(sortedmelanoma_13.head(100), how='inner', on=['Token']).merge(sortedmelanoma_14.head(100), how='inner', on=['Token']).merge(sortedmelanoma_15.head(100), how='inner', on=['Token']).merge(sortedmelanoma_16.head(100), how='inner', on=['Token']).merge(sortedmelanoma_17.head(100), how='inner', on=['Token']).merge(sortedmelanoma_18, how='inner', on=['Token']).merge(sortedmelanoma_1, how='inner', on=['Token']).merge(sortedmelanoma_19.head(100), how='inner', on=['Token']).merge(sortedmelanoma_3.head(100), how='inner', on=['Token']).merge(sortedmelanoma_2.head(100), how='inner', on=['Token']).merge(sortedmelanoma_4.head(100), how='inner', on=['Token']).merge(sortedmelanoma_5, how='inner', on=['Token']).merge(sortedmelanoma_6.head(100), how='inner', on=['Token']).merge(sortedmelanoma_20.head(100), how='inner', on=['Token']).merge(sortedmelanoma_7.head(100), how='inner', on=['Token']).merge(sortedmelanoma_8.head(100), how='inner', on=['Token']).merge(sortedmelanoma_9, how='inner', on=['Token']).merge(sortedmelanoma_10.head(100), how='inner', on=['Token']).merge(sortedmelanoma_21.head(100), how='inner', on=['Token']).merge(sortedmelanoma_22.head(100), how='inner', on=['Token']).merge(sortedmelanoma_23.head(100), how='inner', on=['Token']).merge(sortedmelanoma_24.head(100), how='inner', on=['Token']).merge(sortedmelanoma_25.head(100), how='inner', on=['Token']).merge(sortedmelanoma_26.head(100), how='inner', on=['Token']).merge(sortedmelanoma_27.head(100), how='inner', on=['Token']).merge(sortedmelanoma_28.head(100), how='inner', on=['Token']).merge(sortedmelanoma_29.head(100), how='inner', on=['Token']).merge(sortedmelanoma_30.head(100), how='inner', on=['Token']).merge(sortedmelanoma_31.head(100), how='inner', on=['Token']).merge(sortedmelanoma_32, how='inner', on=['Token']).merge(sortedmelanoma_33.head(100), how='inner', on=['Token']).merge(sortedmelanoma_34.head(100), how='inner', on=['Token']).merge(sortedmelanoma_35.head(100), how='inner', on=['Token']).merge(sortedmelanoma_36.head(100), how='inner', on=['Token']).merge(sortedmelanoma_37.head(100), how='inner', on=['Token']).merge(sortedmelanoma_38.head(100), how='inner', on=['Token']).merge(sortedmelanoma_39.head(100), how='inner', on=['Token']).merge(sortedmelanoma_40.head(100), how='inner', on=['Token']).merge(sortedmelanoma_41.head(100), how='inner', on=['Token']).merge(sortedmelanoma_42.head(100), how='inner', on=['Token']).merge(sortedmelanoma_43.head(100), how='inner', on=['Token']).merge(sortedmelanoma_44.head(100), how='inner', on=['Token']).merge(sortedmelanoma_45.head(100), how='inner', on=['Token']).merge(sortedmelanoma_46.head(100), how='inner', on=['Token']).merge(sortedmelanoma_47.head(100), how='inner', on=['Token']).merge(sortedmelanoma_48.head(100), how='inner', on=['Token']).merge(sortedmelanoma_49.head(100), how='inner', on=['Token']).merge(sortedmelanoma_50.head(100), how='inner', on=['Token']).merge(sortedmelanoma_51.head(100), how='inner', on=['Token']).merge(sortedmelanoma_52.head(100), how='inner', on=['Token']).merge(sortedmelanoma_53.head(100), how='inner', on=['Token']).merge(sortedmelanoma_54.head(100), how='inner', on=['Token']).merge(sortedmelanoma_55.head(100), how='inner', on=['Token']).merge(sortedmelanoma_56.head(100), how='inner', on=['Token']).merge(sortedmelanoma_57.head(100), how='inner', on=['Token']).merge(sortedmelanoma_58.head(100), how='inner', on=['Token']).merge(sortedmelanoma_59.head(100), how='inner', on=['Token']).merge(sortedmelanoma_60.head(100), how='inner', on=['Token']).merge(sortedmelanoma_61.head(100), how='inner', on=['Token']).merge(sortedmelanoma_62.head(100), how='inner', on=['Token']).merge(sortedmelanoma_63.head(100), how='inner', on=['Token']).merge(sortedmelanoma_64.head(100), how='inner', on=['Token']).merge(sortedmelanoma_65.head(100), how='inner', on=['Token']).merge(sortedmelanoma_66.head(100), how='inner', on=['Token']).merge(sortedmelanoma_67.head(100), how='inner', on=['Token']).merge(sortedmelanoma_68.head(100), how='inner', on=['Token'])

# %%
top100df
# Out:
#           Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0           C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1           C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2           T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3           T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4           T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5           C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6   3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7   3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8   5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9   5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10  3ACACACACAC     299.0      135.0      216.0      297.0      161.0
# 11  5GTGTGTGTGT     257.0      139.0      192.0      301.0      184.0
# ...

# %%
top1000df = sortedlungad_1.head(1000).merge(sortedlungad_11.head(1000), how='inner', on=['Token']).merge(sortedlungad_12.head(1000), how='inner', on=['Token']).merge(sortedlungad_13.head(1000), how='inner', on=['Token']).merge(sortedlungad_14.head(1000), how='inner', on=['Token']).merge(sortedlungad_15.head(1000), how='inner', on=['Token']).merge(sortedlungad_16.head(1000), how='inner', on=['Token']).merge(sortedlungad_17.head(1000), how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19.head(1000), how='inner', on=['Token']).merge(sortedlungad_3.head(1000), how='inner', on=['Token']).merge(sortedlungad_2.head(1000), how='inner', on=['Token']).merge(sortedlungad_4.head(1000), how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6.head(1000), how='inner', on=['Token']).merge(sortedlungad_20.head(1000), how='inner', on=['Token']).merge(sortedlungad_7.head(1000), how='inner', on=['Token']).merge(sortedlungad_8.head(1000), how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10.head(1000), how='inner', on=['Token']).merge(sortedlungad_21.head(1000), how='inner', on=['Token']).merge(sortedlungad_22.head(1000), how='inner', on=['Token']).merge(sortedlungad_23.head(1000), how='inner', on=['Token']).merge(sortedlungad_24.head(1000), how='inner', on=['Token']).merge(sortedlungad_25.head(1000), how='inner', on=['Token']).merge(sortedlungad_26.head(1000), how='inner', on=['Token']).merge(sortedlungad_27.head(1000), how='inner', on=['Token']).merge(sortedlungad_28.head(1000), how='inner', on=['Token']).merge(sortedlungad_29.head(1000), how='inner', on=['Token']).merge(sortedlungad_30.head(1000), how='inner', on=['Token']).merge(sortedlungad_31.head(1000), how='inner', on=['Token']).merge(sortedlungad_32, how='inner', on=['Token']).merge(sortedlungad_33.head(1000), how='inner', on=['Token']).merge(sortedlungad_34.head(1000), how='inner', on=['Token']).merge(sortedlungad_35.head(1000), how='inner', on=['Token']).merge(sortedlungad_36.head(1000), how='inner', on=['Token']).merge(sortedlungad_37.head(1000), how='inner', on=['Token']).merge(sortedlungad_38.head(1000), how='inner', on=['Token']).merge(sortedlungad_39.head(1000), how='inner', on=['Token']).merge(sortedlungad_40.head(1000), how='inner', on=['Token']).merge(sortedlungad_41.head(1000), how='inner', on=['Token']).merge(sortedlungad_42, how='inner', on=['Token']) .merge(sortedmelanoma_11.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_12.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_13.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_14.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_15.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_16.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_17.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_18, how='inner', on=['Token']).merge(sortedmelanoma_1, how='inner', on=['Token']).merge(sortedmelanoma_19.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_3.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_2.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_4.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_5, how='inner', on=['Token']).merge(sortedmelanoma_6.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_20.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_7.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_8.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_9, how='inner', on=['Token']).merge(sortedmelanoma_10.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_21.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_22.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_23.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_24.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_25.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_26.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_27.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_28.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_29.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_30.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_31.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_32, how='inner', on=['Token']).merge(sortedmelanoma_33.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_34.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_35.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_36.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_37.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_38.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_39.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_40.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_41.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_42.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_43.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_44.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_45.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_46.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_47.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_48.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_49.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_50.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_51.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_52.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_53.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_54.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_55.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_56.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_57.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_58.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_59.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_60.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_61.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_62.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_63.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_64.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_65.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_66.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_67.head(1000), how='inner', on=['Token']).merge(sortedmelanoma_68.head(1000), how='inner', on=['Token'])

# %%
top1000df
# Out:
#            Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0            C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1            C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2            T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3            T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4            T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5            C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6    3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7    3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8    5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9    5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10   3TATATATATA     332.0       11.0       16.0      110.0      165.0
# 11   5TATATATATA     302.0        8.0       10.0      119.0      170.0
# ...

# %%
top10df = sortedlungad_1.head(10).merge(sortedlungad_11.head(10), how='inner', on=['Token']).merge(sortedlungad_12.head(10), how='inner', on=['Token']).merge(sortedlungad_13.head(10), how='inner', on=['Token']).merge(sortedlungad_14.head(10), how='inner', on=['Token']).merge(sortedlungad_15.head(10), how='inner', on=['Token']).merge(sortedlungad_16.head(10), how='inner', on=['Token']).merge(sortedlungad_17.head(10), how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19.head(10), how='inner', on=['Token']).merge(sortedlungad_3.head(10), how='inner', on=['Token']).merge(sortedlungad_2.head(10), how='inner', on=['Token']).merge(sortedlungad_4.head(10), how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6.head(10), how='inner', on=['Token']).merge(sortedlungad_20.head(10), how='inner', on=['Token']).merge(sortedlungad_7.head(10), how='inner', on=['Token']).merge(sortedlungad_8.head(10), how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10.head(10), how='inner', on=['Token']).merge(sortedlungad_21.head(10), how='inner', on=['Token']).merge(sortedlungad_22.head(10), how='inner', on=['Token']).merge(sortedlungad_23.head(10), how='inner', on=['Token']).merge(sortedlungad_24.head(10), how='inner', on=['Token']).merge(sortedlungad_25.head(10), how='inner', on=['Token']).merge(sortedlungad_26.head(10), how='inner', on=['Token']).merge(sortedlungad_27.head(10), how='inner', on=['Token']).merge(sortedlungad_28.head(10), how='inner', on=['Token']).merge(sortedlungad_29.head(10), how='inner', on=['Token']).merge(sortedlungad_30.head(10), how='inner', on=['Token']).merge(sortedlungad_31.head(10), how='inner', on=['Token']).merge(sortedlungad_32, how='inner', on=['Token']).merge(sortedlungad_33.head(10), how='inner', on=['Token']).merge(sortedlungad_34.head(10), how='inner', on=['Token']).merge(sortedlungad_35.head(10), how='inner', on=['Token']).merge(sortedlungad_36.head(10), how='inner', on=['Token']).merge(sortedlungad_37.head(10), how='inner', on=['Token']).merge(sortedlungad_38.head(10), how='inner', on=['Token']).merge(sortedlungad_39.head(10), how='inner', on=['Token']).merge(sortedlungad_40.head(10), how='inner', on=['Token']).merge(sortedlungad_41.head(10), how='inner', on=['Token']).merge(sortedlungad_42, how='inner', on=['Token']) .merge(sortedmelanoma_11.head(10), how='inner', on=['Token']).merge(sortedmelanoma_12.head(10), how='inner', on=['Token']).merge(sortedmelanoma_13.head(10), how='inner', on=['Token']).merge(sortedmelanoma_14.head(10), how='inner', on=['Token']).merge(sortedmelanoma_15.head(10), how='inner', on=['Token']).merge(sortedmelanoma_16.head(10), how='inner', on=['Token']).merge(sortedmelanoma_17.head(10), how='inner', on=['Token']).merge(sortedmelanoma_18, how='inner', on=['Token']).merge(sortedmelanoma_1, how='inner', on=['Token']).merge(sortedmelanoma_19.head(10), how='inner', on=['Token']).merge(sortedmelanoma_3.head(10), how='inner', on=['Token']).merge(sortedmelanoma_2.head(10), how='inner', on=['Token']).merge(sortedmelanoma_4.head(10), how='inner', on=['Token']).merge(sortedmelanoma_5, how='inner', on=['Token']).merge(sortedmelanoma_6.head(10), how='inner', on=['Token']).merge(sortedmelanoma_20.head(10), how='inner', on=['Token']).merge(sortedmelanoma_7.head(10), how='inner', on=['Token']).merge(sortedmelanoma_8.head(10), how='inner', on=['Token']).merge(sortedmelanoma_9, how='inner', on=['Token']).merge(sortedmelanoma_10.head(10), how='inner', on=['Token']).merge(sortedmelanoma_21.head(10), how='inner', on=['Token']).merge(sortedmelanoma_22.head(10), how='inner', on=['Token']).merge(sortedmelanoma_23.head(10), how='inner', on=['Token']).merge(sortedmelanoma_24.head(10), how='inner', on=['Token']).merge(sortedmelanoma_25.head(10), how='inner', on=['Token']).merge(sortedmelanoma_26.head(10), how='inner', on=['Token']).merge(sortedmelanoma_27.head(10), how='inner', on=['Token']).merge(sortedmelanoma_28.head(10), how='inner', on=['Token']).merge(sortedmelanoma_29.head(10), how='inner', on=['Token']).merge(sortedmelanoma_30.head(10), how='inner', on=['Token']).merge(sortedmelanoma_31.head(10), how='inner', on=['Token']).merge(sortedmelanoma_32, how='inner', on=['Token']).merge(sortedmelanoma_33.head(10), how='inner', on=['Token']).merge(sortedmelanoma_34.head(10), how='inner', on=['Token']).merge(sortedmelanoma_35.head(10), how='inner', on=['Token']).merge(sortedmelanoma_36.head(10), how='inner', on=['Token']).merge(sortedmelanoma_37.head(10), how='inner', on=['Token']).merge(sortedmelanoma_38.head(10), how='inner', on=['Token']).merge(sortedmelanoma_39.head(10), how='inner', on=['Token']).merge(sortedmelanoma_40.head(10), how='inner', on=['Token']).merge(sortedmelanoma_41.head(10), how='inner', on=['Token']).merge(sortedmelanoma_42.head(10), how='inner', on=['Token']).merge(sortedmelanoma_43.head(10), how='inner', on=['Token']).merge(sortedmelanoma_44.head(10), how='inner', on=['Token']).merge(sortedmelanoma_45.head(10), how='inner', on=['Token']).merge(sortedmelanoma_46.head(10), how='inner', on=['Token']).merge(sortedmelanoma_47.head(10), how='inner', on=['Token']).merge(sortedmelanoma_48.head(10), how='inner', on=['Token']).merge(sortedmelanoma_49.head(10), how='inner', on=['Token']).merge(sortedmelanoma_50.head(10), how='inner', on=['Token']).merge(sortedmelanoma_51.head(10), how='inner', on=['Token']).merge(sortedmelanoma_52.head(10), how='inner', on=['Token']).merge(sortedmelanoma_53.head(10), how='inner', on=['Token']).merge(sortedmelanoma_54.head(10), how='inner', on=['Token']).merge(sortedmelanoma_55.head(10), how='inner', on=['Token']).merge(sortedmelanoma_56.head(10), how='inner', on=['Token']).merge(sortedmelanoma_57.head(10), how='inner', on=['Token']).merge(sortedmelanoma_58.head(10), how='inner', on=['Token']).merge(sortedmelanoma_59.head(10), how='inner', on=['Token']).merge(sortedmelanoma_60.head(10), how='inner', on=['Token']).merge(sortedmelanoma_61.head(10), how='inner', on=['Token']).merge(sortedmelanoma_62.head(10), how='inner', on=['Token']).merge(sortedmelanoma_63.head(10), how='inner', on=['Token']).merge(sortedmelanoma_64.head(10), how='inner', on=['Token']).merge(sortedmelanoma_65.head(10), how='inner', on=['Token']).merge(sortedmelanoma_66.head(10), how='inner', on=['Token']).merge(sortedmelanoma_67.head(10), how='inner', on=['Token']).merge(sortedmelanoma_68.head(10), how='inner', on=['Token'])

# %%
top10df
# Out:
#          Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0          C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1          C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2          T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3          T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4          T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5          C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6  3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7  3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8  5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9  5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
#
#    lungad_15  lungad_16  lungad_17  lungad_18     ...       melanoma_59  \
# 0    32115.0    20664.0    15809.0    12431.0     ...            6042.0
# ...

# %%
# %store top100df >> top100LungMel.csv
# %store top10df >> top10LungMel.csv
# %store top1000df >> top1000LungMel.csv
# Out:
# Writing 'top100df' (DataFrame) to file 'top100LungMel.csv'.
# Writing 'top10df' (DataFrame) to file 'top10LungMel.csv'.
# Writing 'top1000df' (DataFrame) to file 'top1000LungMel.csv'.

# %%
top10000df = sortedlungad_1.head(10000).merge(sortedlungad_11.head(10000), how='inner', on=['Token']).merge(sortedlungad_12.head(10000), how='inner', on=['Token']).merge(sortedlungad_13.head(10000), how='inner', on=['Token']).merge(sortedlungad_14.head(10000), how='inner', on=['Token']).merge(sortedlungad_15.head(10000), how='inner', on=['Token']).merge(sortedlungad_16.head(10000), how='inner', on=['Token']).merge(sortedlungad_17.head(10000), how='inner', on=['Token']).merge(sortedlungad_18, how='inner', on=['Token']).merge(sortedlungad_19.head(10000), how='inner', on=['Token']).merge(sortedlungad_3.head(10000), how='inner', on=['Token']).merge(sortedlungad_2.head(10000), how='inner', on=['Token']).merge(sortedlungad_4.head(10000), how='inner', on=['Token']).merge(sortedlungad_5, how='inner', on=['Token']).merge(sortedlungad_6.head(10000), how='inner', on=['Token']).merge(sortedlungad_20.head(10000), how='inner', on=['Token']).merge(sortedlungad_7.head(10000), how='inner', on=['Token']).merge(sortedlungad_8.head(10000), how='inner', on=['Token']).merge(sortedlungad_9, how='inner', on=['Token']).merge(sortedlungad_10.head(10000), how='inner', on=['Token']).merge(sortedlungad_21.head(10000), how='inner', on=['Token']).merge(sortedlungad_22.head(10000), how='inner', on=['Token']).merge(sortedlungad_23.head(10000), how='inner', on=['Token']).merge(sortedlungad_24.head(10000), how='inner', on=['Token']).merge(sortedlungad_25.head(10000), how='inner', on=['Token']).merge(sortedlungad_26.head(10000), how='inner', on=['Token']).merge(sortedlungad_27.head(10000), how='inner', on=['Token']).merge(sortedlungad_28.head(10000), how='inner', on=['Token']).merge(sortedlungad_29.head(10000), how='inner', on=['Token']).merge(sortedlungad_30.head(10000), how='inner', on=['Token']).merge(sortedlungad_31.head(10000), how='inner', on=['Token']).merge(sortedlungad_32, how='inner', on=['Token']).merge(sortedlungad_33.head(10000), how='inner', on=['Token']).merge(sortedlungad_34.head(10000), how='inner', on=['Token']).merge(sortedlungad_35.head(10000), how='inner', on=['Token']).merge(sortedlungad_36.head(10000), how='inner', on=['Token']).merge(sortedlungad_37.head(10000), how='inner', on=['Token']).merge(sortedlungad_38.head(10000), how='inner', on=['Token']).merge(sortedlungad_39.head(10000), how='inner', on=['Token']).merge(sortedlungad_40.head(10000), how='inner', on=['Token']).merge(sortedlungad_41.head(10000), how='inner', on=['Token']).merge(sortedlungad_42, how='inner', on=['Token']) .merge(sortedmelanoma_11.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_12.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_13.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_14.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_15.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_16.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_17.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_18, how='inner', on=['Token']).merge(sortedmelanoma_1, how='inner', on=['Token']).merge(sortedmelanoma_19.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_3.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_2.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_4.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_5, how='inner', on=['Token']).merge(sortedmelanoma_6.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_20.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_7.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_8.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_9, how='inner', on=['Token']).merge(sortedmelanoma_10.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_21.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_22.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_23.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_24.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_25.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_26.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_27.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_28.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_29.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_30.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_31.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_32, how='inner', on=['Token']).merge(sortedmelanoma_33.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_34.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_35.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_36.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_37.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_38.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_39.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_40.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_41.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_42.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_43.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_44.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_45.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_46.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_47.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_48.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_49.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_50.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_51.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_52.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_53.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_54.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_55.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_56.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_57.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_58.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_59.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_60.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_61.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_62.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_63.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_64.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_65.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_66.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_67.head(10000), how='inner', on=['Token']).merge(sortedmelanoma_68.head(10000), how='inner', on=['Token'])

# %%
top10000df
# Out:
#            Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 0            C>A   25513.0     7185.0    31868.0     6412.0     4826.0
# 1            C>T   16704.0     8555.0    19915.0    14734.0    10373.0
# 2            T>C   10451.0     5720.0    13557.0    12597.0     9031.0
# 3            T>A    9728.0     3425.0    10743.0     6238.0     4491.0
# 4            T>G    5838.0     3494.0     7001.0     6216.0     5021.0
# 5            C>G    3505.0     2331.0     5179.0     3096.0     2162.0
# 6    3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7    3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
# 8    5AAAAAAAAAA     904.0      299.0      453.0      398.0      451.0
# 9    5TTTTTTTTTT     811.0      263.0      410.0      356.0      429.0
# 10   3TATATATATA     332.0       11.0       16.0      110.0      165.0
# 11   5TATATATATA     302.0        8.0       10.0      119.0      170.0
# ...

# %%
# %store top10000df >> top10000LungMel.csv
# Out:
# Writing 'top10000df' (DataFrame) to file 'top10000LungMel.csv'.

# %%
top10df.to_csv("top10LungMel.csv", sep=",", index=False)
top100df.to_csv("top100LungMel.csv", sep=",",index=False)
top1000df.to_csv("top1000LungMel.csv", sep=",", index=False)
top10000df.to_csv("top10000LungMel.csv", sep=",", index=False)

# %%
top10df[top10df['Token'].str.match('3')]
# Out:
#          Token  lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  \
# 6  3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0
# 7  3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0
#
#    lungad_15  lungad_16  lungad_17  lungad_18     ...       melanoma_59  \
# 6      669.0     1039.0     2932.0     4205.0     ...            1229.0
# 7      802.0      692.0     2913.0     4184.0     ...            1320.0
#
#    melanoma_60  melanoma_61  melanoma_62  melanoma_63  melanoma_64  \
# 6       1209.0       4622.0       1143.0       3932.0       4327.0
# 7       1323.0       5135.0       1367.0       4606.0       4614.0
#
#    melanoma_65  melanoma_66  melanoma_67  melanoma_68
# 6       2429.0       2035.0       1360.0       2025.0
# 7       2867.0       2393.0       1536.0       2631.0
#
# [2 rows x 111 columns]

# %%
df = top10df[top10df['Token'].str.match('3')]

# %%
df2 = df.sum(axis=0)

# %%
df2.columns =['Cancer', 'Sum']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c7713b4a72db> in <module>()
# ----> 1 df2['3AAAAAAAAAA3TTTTTTTTTT']
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.22.0-py2.7-linux-x86_64.egg/pandas/core/series.pyc in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.22.0-py2.7-linux-x86_64.egg/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    2572                     raise InvalidIndexError(key)
#    2573                 else:
# -> 2574                     raise e1
#    2575             except Exception:  # pragma: no cover
#    2576                 raise e1
#
# KeyError: '3AAAAAAAAAA3TTTTTTTTTT'

# %%
new =top10df.set_index('Token').filter(regex='3', axis=0)

# %%
new
# Out:
#              lungad_1  lungad_11  lungad_12  lungad_13  lungad_14  lungad_15  \
# Token
# 3AAAAAAAAAA    1793.0      607.0      827.0      887.0     1147.0      669.0
# 3TTTTTTTTTT    1609.0      506.0      808.0      683.0      834.0      802.0
#
#              lungad_16  lungad_17  lungad_18  lungad_19     ...       \
# Token                                                       ...
# 3AAAAAAAAAA     1039.0     2932.0     4205.0     1686.0     ...
# 3TTTTTTTTTT      692.0     2913.0     4184.0     1218.0     ...
#
#              melanoma_59  melanoma_60  melanoma_61  melanoma_62  melanoma_63  \
# Token
# 3AAAAAAAAAA       1229.0       1209.0       4622.0       1143.0       3932.0
# 3TTTTTTTTTT       1320.0       1323.0       5135.0       1367.0       4606.0
#
#              melanoma_64  melanoma_65  melanoma_66  melanoma_67  melanoma_68
# Token
# 3AAAAAAAAAA       4327.0       2429.0       2035.0       1360.0       2025.0
# ...

# %%
d
