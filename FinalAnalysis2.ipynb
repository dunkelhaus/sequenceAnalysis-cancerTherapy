# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
from sqlalchemy import create_engine
import sqlite3
import matplotlib.pyplot as plt

# %%
csv_database = create_engine('sqlite:///csv_database.db')

# %%
file = "/home/skjena/cancerTherapy/modules/RawDB/scripts/fm_sample_independent_transpose.csv"

# %%
print pd.read_csv(file, nrows=5)
# Out:
#          Token  lungad_10  lungad_1  lungad_11  lungad_12  lungad_13  \
# 0  3AAAAAAAAAA       1081      1793        607        827        887
# 1  3AAAAAAAAAC         36        47         21         42         21
# 2  3AAAAAAAAAG         35        45         21         29         28
# 3  3AAAAAAAAAT         31        29         12         25         29
# 4  3AAAAAAAACA         20        21         14         18         14
#
#    lungad_14  lungad_15  lungad_16  lungad_17     ...      melanoma_62  \
# 0       1147        669       1039       2932     ...             1143
# 1         18         34         25         96     ...               35
# 2         21         39         31        129     ...               44
# 3         17         24         19        116     ...               37
# 4         13         18         12         54     ...               16
#
#    melanoma_63  melanoma_64  melanoma_65  melanoma_66  melanoma_67  \
# ...

# %%
chunksize = 100000
i = 0
j = 1
for df in pd.read_csv(file, chunksize=chunksize, iterator=True):
      df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
      df.index += j
      i+=1
      df.to_sql('mutations', csv_database, if_exists='append')
      j = df.index[-1] + 1

# %%
csv_database.execute('select Token from mutations').fetchall()
# Out:
# [(u'3AAAAAAAAAA',),
#  (u'3AAAAAAAAAC',),
#  (u'3AAAAAAAAAG',),
#  (u'3AAAAAAAAAT',),
#  (u'3AAAAAAAACA',),
#  (u'3AAAAAAAACC',),
#  (u'3AAAAAAAACG',),
#  (u'3AAAAAAAACT',),
#  (u'3AAAAAAAAGA',),
#  (u'3AAAAAAAAGC',),
#  (u'3AAAAAAAAGG',),
#  (u'3AAAAAAAAGT',),
#  (u'3AAAAAAAATA',),
#  (u'3AAAAAAAATC',),
#  (u'3AAAAAAAATG',),
#  (u'3AAAAAAAATT',),
#  (u'3AAAAAAACAA',),
#  (u'3AAAAAAACAC',),
#  (u'3AAAAAAACAG',),
#  (u'3AAAAAAACAT',),
#  (u'3AAAAAAACCA',),
#  (u'3AAAAAAACCC',),
#  (u'3AAAAAAACCT',),
#  (u'3AAAAAAACGG',),
#  (u'3AAAAAAACTA',),
#  (u'3AAAAAAACTC',),
#  (u'3AAAAAAACTG',),
#  (u'3AAAAAAACTT',),
#  (u'3AAAAAAAGAA',),
#  (u'3AAAAAAAGAC',),
#  (u'3AAAAAAAGAG',),
#  (u'3AAAAAAAGAT',),
#  (u'3AAAAAAAGCC',),
#  (u'3AAAAAAAGCT',),
#  (u'3AAAAAAAGGA',),
#  (u'3AAAAAAAGGC',),
#  (u'3AAAAAAAGGG',),
#  (u'3AAAAAAAGGT',),
#  (u'3AAAAAAAGTA',),
#  (u'3AAAAAAAGTG',),
#  (u'3AAAAAAAGTT',),
#  (u'3AAAAAAATAA',),
#  (u'3AAAAAAATAC',),
#  (u'3AAAAAAATAG',),
#  (u'3AAAAAAATAT',),
# ...

# %%
csv_database.execute("PRAGMA table_info(mutations)").fetchall()
# Out:
# [(0, u'index', u'BIGINT', 0, None, 0),
#  (1, u'Token', u'TEXT', 0, None, 0),
#  (2, u'lungad_10', u'BIGINT', 0, None, 0),
#  (3, u'lungad_1', u'FLOAT', 0, None, 0),
#  (4, u'lungad_11', u'FLOAT', 0, None, 0),
#  (5, u'lungad_12', u'FLOAT', 0, None, 0),
#  (6, u'lungad_13', u'FLOAT', 0, None, 0),
#  (7, u'lungad_14', u'FLOAT', 0, None, 0),
#  (8, u'lungad_15', u'FLOAT', 0, None, 0),
#  (9, u'lungad_16', u'FLOAT', 0, None, 0),
#  (10, u'lungad_17', u'FLOAT', 0, None, 0),
#  (11, u'lungad_18', u'FLOAT', 0, None, 0),
#  (12, u'lungad_19', u'FLOAT', 0, None, 0),
#  (13, u'lungad_20', u'FLOAT', 0, None, 0),
#  (14, u'lungad_2', u'FLOAT', 0, None, 0),
#  (15, u'lungad_21', u'FLOAT', 0, None, 0),
#  (16, u'lungad_22', u'FLOAT', 0, None, 0),
#  (17, u'lungad_23', u'FLOAT', 0, None, 0),
#  (18, u'lungad_24', u'FLOAT', 0, None, 0),
#  (19, u'lungad_25', u'FLOAT', 0, None, 0),
#  (20, u'lungad_26', u'FLOAT', 0, None, 0),
#  (21, u'lungad_27', u'FLOAT', 0, None, 0),
# ...

# %%
lungad_1df = pd.read_sql_query('select Token, lungad_1 from mutations',csv_database)
lungad_11df = pd.read_sql_query('select Token, lungad_11 from mutations',csv_database)
lungad_12df = pd.read_sql_query('select Token, lungad_12 from mutations',csv_database)
lungad_13df = pd.read_sql_query('select Token, lungad_13 from mutations',csv_database)
lungad_14df = pd.read_sql_query('select Token, lungad_14 from mutations',csv_database)
lungad_15df = pd.read_sql_query('select Token, lungad_15 from mutations',csv_database)
lungad_16df = pd.read_sql_query('select Token, lungad_16 from mutations',csv_database)
lungad_17df = pd.read_sql_query('select Token, lungad_17 from mutations',csv_database)
lungad_18df = pd.read_sql_query('select Token, lungad_18 from mutations',csv_database)
lungad_19df = pd.read_sql_query('select Token, lungad_19 from mutations',csv_database)
lungad_20df = pd.read_sql_query('select Token, lungad_20 from mutations',csv_database)

# %%
lungad_2df = pd.read_sql_query('select Token, lungad_2 from mutations',csv_database)
lungad_21df = pd.read_sql_query('select Token, lungad_21 from mutations',csv_database)
lungad_22df = pd.read_sql_query('select Token, lungad_22 from mutations',csv_database)
lungad_23df = pd.read_sql_query('select Token, lungad_23 from mutations',csv_database)
lungad_24df = pd.read_sql_query('select Token, lungad_24 from mutations',csv_database)
lungad_25df = pd.read_sql_query('select Token, lungad_25 from mutations',csv_database)
lungad_26df = pd.read_sql_query('select Token, lungad_26 from mutations',csv_database)
lungad_27df = pd.read_sql_query('select Token, lungad_27 from mutations',csv_database)
lungad_28df = pd.read_sql_query('select Token, lungad_28 from mutations',csv_database)
lungad_29df = pd.read_sql_query('select Token, lungad_29 from mutations',csv_database)
lungad_30df = pd.read_sql_query('select Token, lungad_30 from mutations',csv_database)

# %%
lungad_3df = pd.read_sql_query('select Token, lungad_3 from mutations',csv_database)
lungad_31df = pd.read_sql_query('select Token, lungad_31 from mutations',csv_database)
lungad_32df = pd.read_sql_query('select Token, lungad_32 from mutations',csv_database)
lungad_33df = pd.read_sql_query('select Token, lungad_33 from mutations',csv_database)
lungad_34df = pd.read_sql_query('select Token, lungad_34 from mutations',csv_database)
lungad_35df = pd.read_sql_query('select Token, lungad_35 from mutations',csv_database)
lungad_36df = pd.read_sql_query('select Token, lungad_36 from mutations',csv_database)
lungad_37df = pd.read_sql_query('select Token, lungad_37 from mutations',csv_database)
lungad_38df = pd.read_sql_query('select Token, lungad_38 from mutations',csv_database)
lungad_39df = pd.read_sql_query('select Token, lungad_39 from mutations',csv_database)
lungad_40df = pd.read_sql_query('select Token, lungad_40 from mutations',csv_database)

# %%
lungad_4df = pd.read_sql_query('select Token, lungad_4 from mutations',csv_database)
lungad_41df = pd.read_sql_query('select Token, lungad_41 from mutations',csv_database)
lungad_42df = pd.read_sql_query('select Token, lungad_42 from mutations',csv_database)
lungad_5df = pd.read_sql_query('select Token, lungad_5 from mutations',csv_database)
lungad_6df = pd.read_sql_query('select Token, lungad_6 from mutations',csv_database)
lungad_7df = pd.read_sql_query('select Token, lungad_7 from mutations',csv_database)
lungad_8df = pd.read_sql_query('select Token, lungad_8 from mutations',csv_database)
lungad_9df = pd.read_sql_query('select Token, lungad_9 from mutations',csv_database)

# %%
lungad_10df =pd.read_sql_query('select Token, lungad_10 from mutations',csv_database)

# %%
lungad_11df
# Out:
#                Token  lungad_11
# 0        3AAAAAAAAAA      607.0
# 1        3AAAAAAAAAC       21.0
# 2        3AAAAAAAAAG       21.0
# 3        3AAAAAAAAAT       12.0
# 4        3AAAAAAAACA       14.0
# 5        3AAAAAAAACC        9.0
# 6        3AAAAAAAACG        1.0
# 7        3AAAAAAAACT        3.0
# 8        3AAAAAAAAGA       14.0
# 9        3AAAAAAAAGC        2.0
# 10       3AAAAAAAAGG        1.0
# 11       3AAAAAAAAGT        5.0
# 12       3AAAAAAAATA        2.0
# 13       3AAAAAAAATC        3.0
# 14       3AAAAAAAATG        2.0
# 15       3AAAAAAAATT        4.0
# 16       3AAAAAAACAA        8.0
# 17       3AAAAAAACAC        NaN
# 18       3AAAAAAACAG        1.0
# 19       3AAAAAAACAT        NaN
# 20       3AAAAAAACCA        4.0
# 21       3AAAAAAACCC        1.0
# 22       3AAAAAAACCT        1.0
# 23       3AAAAAAACGG        NaN
# 24       3AAAAAAACTA        NaN
# 25       3AAAAAAACTC        NaN
# 26       3AAAAAAACTG        1.0
# 27       3AAAAAAACTT        3.0
# ...

# %%
sortedlungad_1 = lungad_1df.sort_values('lungad_1', ascending=False)
sortedlungad_2 = lungad_2df.sort_values('lungad_2', ascending=False)
sortedlungad_3 = lungad_3df.sort_values('lungad_3', ascending=False)
sortedlungad_4 = lungad_4df.sort_values('lungad_4', ascending=False)
sortedlungad_5 = lungad_5df.sort_values('lungad_5', ascending=False)
sortedlungad_6 = lungad_6df.sort_values('lungad_6', ascending=False)
sortedlungad_7 = lungad_7df.sort_values('lungad_7', ascending=False)
sortedlungad_8 = lungad_8df.sort_values('lungad_8', ascending=False)
sortedlungad_9 = lungad_9df.sort_values('lungad_9', ascending=False)
sortedlungad_10 = lungad_10df.sort_values('lungad_10', ascending=False)

# %%
sortedlungad_11 = lungad_11df.sort_values('lungad_11', ascending=False)
sortedlungad_12 = lungad_12df.sort_values('lungad_12', ascending=False)
sortedlungad_13 = lungad_13df.sort_values('lungad_13', ascending=False)
sortedlungad_14 = lungad_14df.sort_values('lungad_14', ascending=False)
sortedlungad_15 = lungad_15df.sort_values('lungad_15', ascending=False)
sortedlungad_16 = lungad_16df.sort_values('lungad_16', ascending=False)
sortedlungad_17 = lungad_17df.sort_values('lungad_17', ascending=False)
sortedlungad_18 = lungad_18df.sort_values('lungad_18', ascending=False)
sortedlungad_19 = lungad_19df.sort_values('lungad_19', ascending=False)
sortedlungad_20 = lungad_20df.sort_values('lungad_20', ascending=False)

# %%
sortedlungad_21 = lungad_21df.sort_values('lungad_21', ascending=False)
sortedlungad_22 = lungad_22df.sort_values('lungad_22', ascending=False)
sortedlungad_23 = lungad_23df.sort_values('lungad_23', ascending=False)
sortedlungad_24 = lungad_24df.sort_values('lungad_24', ascending=False)
sortedlungad_25 = lungad_25df.sort_values('lungad_25', ascending=False)
sortedlungad_26 = lungad_26df.sort_values('lungad_26', ascending=False)
sortedlungad_27 = lungad_27df.sort_values('lungad_27', ascending=False)
sortedlungad_28 = lungad_28df.sort_values('lungad_28', ascending=False)
sortedlungad_29 = lungad_29df.sort_values('lungad_29', ascending=False)
sortedlungad_30 = lungad_30df.sort_values('lungad_30', ascending=False)

# %%
sortedlungad_31 = lungad_31df.sort_values('lungad_31', ascending=False)
sortedlungad_32 = lungad_32df.sort_values('lungad_32', ascending=False)
sortedlungad_33 = lungad_33df.sort_values('lungad_33', ascending=False)
sortedlungad_34 = lungad_34df.sort_values('lungad_34', ascending=False)
sortedlungad_35 = lungad_35df.sort_values('lungad_35', ascending=False)
sortedlungad_36 = lungad_36df.sort_values('lungad_36', ascending=False)
sortedlungad_37 = lungad_37df.sort_values('lungad_37', ascending=False)
sortedlungad_38 = lungad_38df.sort_values('lungad_38', ascending=False)
sortedlungad_39 = lungad_39df.sort_values('lungad_39', ascending=False)
sortedlungad_40 = lungad_40df.sort_values('lungad_40', ascending=False)

# %%
sortedlungad_41 = lungad_41df.sort_values('lungad_41', ascending=False)
sortedlungad_42 = lungad_42df.sort_values('lungad_42', ascending=False)

# %%
melanoma_10df = pd.read_sql_query('select Token, melanoma_10 from mutations',csv_database)
melanoma_1df = pd.read_sql_query('select Token, melanoma_1 from mutations',csv_database)
melanoma_11df = pd.read_sql_query('select Token, melanoma_11 from mutations',csv_database)
melanoma_12df = pd.read_sql_query('select Token, melanoma_12 from mutations',csv_database)
melanoma_13df = pd.read_sql_query('select Token, melanoma_13 from mutations',csv_database)
melanoma_14df = pd.read_sql_query('select Token, melanoma_14 from mutations',csv_database)
melanoma_15df = pd.read_sql_query('select Token, melanoma_15 from mutations',csv_database)
melanoma_16df = pd.read_sql_query('select Token, melanoma_16 from mutations',csv_database)
melanoma_17df = pd.read_sql_query('select Token, melanoma_17 from mutations',csv_database)
melanoma_18df = pd.read_sql_query('select Token, melanoma_18 from mutations',csv_database)
melanoma_19df = pd.read_sql_query('select Token, melanoma_19 from mutations',csv_database)
melanoma_20df = pd.read_sql_query('select Token, melanoma_20 from mutations',csv_database)

# %%
melanoma_2df = pd.read_sql_query('select Token, melanoma_2 from mutations',csv_database)
melanoma_21df = pd.read_sql_query('select Token, melanoma_21 from mutations',csv_database)
melanoma_22df = pd.read_sql_query('select Token, melanoma_22 from mutations',csv_database)
melanoma_23df = pd.read_sql_query('select Token, melanoma_23 from mutations',csv_database)
melanoma_24df = pd.read_sql_query('select Token, melanoma_24 from mutations',csv_database)
melanoma_25df = pd.read_sql_query('select Token, melanoma_25 from mutations',csv_database)
melanoma_26df = pd.read_sql_query('select Token, melanoma_26 from mutations',csv_database)
melanoma_27df = pd.read_sql_query('select Token, melanoma_27 from mutations',csv_database)
melanoma_28df = pd.read_sql_query('select Token, melanoma_28 from mutations',csv_database)
melanoma_29df = pd.read_sql_query('select Token, melanoma_29 from mutations',csv_database)
melanoma_30df = pd.read_sql_query('select Token, melanoma_30 from mutations',csv_database)

# %%
melanoma_3df = pd.read_sql_query('select Token, melanoma_3 from mutations',csv_database)
melanoma_31df = pd.read_sql_query('select Token, melanoma_31 from mutations',csv_database)
melanoma_32df = pd.read_sql_query('select Token, melanoma_32 from mutations',csv_database)
melanoma_33df = pd.read_sql_query('select Token, melanoma_33 from mutations',csv_database)
melanoma_34df = pd.read_sql_query('select Token, melanoma_34 from mutations',csv_database)
melanoma_35df = pd.read_sql_query('select Token, melanoma_35 from mutations',csv_database)
melanoma_36df = pd.read_sql_query('select Token, melanoma_36 from mutations',csv_database)
melanoma_37df = pd.read_sql_query('select Token, melanoma_37 from mutations',csv_database)
melanoma_38df = pd.read_sql_query('select Token, melanoma_38 from mutations',csv_database)
melanoma_39df = pd.read_sql_query('select Token, melanoma_39 from mutations',csv_database)
melanoma_40df = pd.read_sql_query('select Token, melanoma_40 from mutations',csv_database)

# %%
melanoma_4df = pd.read_sql_query('select Token, melanoma_4 from mutations',csv_database)
melanoma_41df = pd.read_sql_query('select Token, melanoma_41 from mutations',csv_database)
melanoma_42df = pd.read_sql_query('select Token, melanoma_42 from mutations',csv_database)
melanoma_43df = pd.read_sql_query('select Token, melanoma_43 from mutations',csv_database)
melanoma_44df = pd.read_sql_query('select Token, melanoma_44 from mutations',csv_database)
melanoma_45df = pd.read_sql_query('select Token, melanoma_45 from mutations',csv_database)
melanoma_46df = pd.read_sql_query('select Token, melanoma_46 from mutations',csv_database)
melanoma_47df = pd.read_sql_query('select Token, melanoma_47 from mutations',csv_database)
melanoma_48df = pd.read_sql_query('select Token, melanoma_48 from mutations',csv_database)
melanoma_49df = pd.read_sql_query('select Token, melanoma_49 from mutations',csv_database)
melanoma_50df = pd.read_sql_query('select Token, melanoma_50 from mutations',csv_database)

# %%
melanoma_5df = pd.read_sql_query('select Token, melanoma_5 from mutations',csv_database)
melanoma_51df = pd.read_sql_query('select Token, melanoma_51 from mutations',csv_database)
melanoma_52df = pd.read_sql_query('select Token, melanoma_52 from mutations',csv_database)
melanoma_53df = pd.read_sql_query('select Token, melanoma_53 from mutations',csv_database)
melanoma_54df = pd.read_sql_query('select Token, melanoma_54 from mutations',csv_database)
melanoma_55df = pd.read_sql_query('select Token, melanoma_55 from mutations',csv_database)
melanoma_56df = pd.read_sql_query('select Token, melanoma_56 from mutations',csv_database)
melanoma_57df = pd.read_sql_query('select Token, melanoma_57 from mutations',csv_database)
melanoma_58df = pd.read_sql_query('select Token, melanoma_58 from mutations',csv_database)
melanoma_59df = pd.read_sql_query('select Token, melanoma_59 from mutations',csv_database)
melanoma_60df = pd.read_sql_query('select Token, melanoma_60 from mutations',csv_database)

# %%
melanoma_6df = pd.read_sql_query('select Token, melanoma_6 from mutations',csv_database)
melanoma_61df = pd.read_sql_query('select Token, melanoma_61 from mutations',csv_database)
melanoma_62df = pd.read_sql_query('select Token, melanoma_62 from mutations',csv_database)
melanoma_63df = pd.read_sql_query('select Token, melanoma_63 from mutations',csv_database)
melanoma_64df = pd.read_sql_query('select Token, melanoma_64 from mutations',csv_database)
melanoma_65df = pd.read_sql_query('select Token, melanoma_65 from mutations',csv_database)
melanoma_66df = pd.read_sql_query('select Token, melanoma_66 from mutations',csv_database)
melanoma_67df = pd.read_sql_query('select Token, melanoma_67 from mutations',csv_database)
melanoma_68df = pd.read_sql_query('select Token, melanoma_68 from mutations',csv_database)

# %%
melanoma_7df = pd.read_sql_query('select Token, melanoma_7 from mutations',csv_database)
melanoma_8df = pd.read_sql_query('select Token, melanoma_8 from mutations',csv_database)
melanoma_9df = pd.read_sql_query('select Token, melanoma_9 from mutations',csv_database)

# %%
sortedmelanoma_1 = melanoma_1df.sort_values('melanoma_1', ascending=False)
sortedmelanoma_2 = melanoma_2df.sort_values('melanoma_2', ascending=False)
sortedmelanoma_3 = melanoma_3df.sort_values('melanoma_3', ascending=False)
sortedmelanoma_4 = melanoma_4df.sort_values('melanoma_4', ascending=False)
sortedmelanoma_5 = melanoma_5df.sort_values('melanoma_5', ascending=False)
sortedmelanoma_6 = melanoma_6df.sort_values('melanoma_6', ascending=False)
sortedmelanoma_7 = melanoma_7df.sort_values('melanoma_7', ascending=False)
sortedmelanoma_8 = melanoma_8df.sort_values('melanoma_8', ascending=False)
sortedmelanoma_9 = melanoma_9df.sort_values('melanoma_9', ascending=False)
sortedmelanoma_10 = melanoma_10df.sort_values('melanoma_10', ascending=False)

# %%
sortedmelanoma_11 = melanoma_11df.sort_values('melanoma_11', ascending=False)
sortedmelanoma_12 = melanoma_12df.sort_values('melanoma_12', ascending=False)
sortedmelanoma_13 = melanoma_13df.sort_values('melanoma_13', ascending=False)
sortedmelanoma_14 = melanoma_14df.sort_values('melanoma_14', ascending=False)
sortedmelanoma_15 = melanoma_15df.sort_values('melanoma_15', ascending=False)
sortedmelanoma_16 = melanoma_16df.sort_values('melanoma_16', ascending=False)
sortedmelanoma_17 = melanoma_17df.sort_values('melanoma_17', ascending=False)
sortedmelanoma_18 = melanoma_18df.sort_values('melanoma_18', ascending=False)
sortedmelanoma_19 = melanoma_19df.sort_values('melanoma_19', ascending=False)
sortedmelanoma_20 = melanoma_20df.sort_values('melanoma_20', ascending=False)

# %%
sortedmelanoma_31 = melanoma_31df.sort_values('melanoma_31', ascending=False)
sortedmelanoma_32 = melanoma_32df.sort_values('melanoma_32', ascending=False)
sortedmelanoma_33 = melanoma_33df.sort_values('melanoma_33', ascending=False)
sortedmelanoma_34 = melanoma_34df.sort_values('melanoma_34', ascending=False)
sortedmelanoma_35 = melanoma_35df.sort_values('melanoma_35', ascending=False)
sortedmelanoma_36 = melanoma_36df.sort_values('melanoma_36', ascending=False)
sortedmelanoma_37 = melanoma_37df.sort_values('melanoma_37', ascending=False)
sortedmelanoma_38 = melanoma_38df.sort_values('melanoma_38', ascending=False)
sortedmelanoma_39 = melanoma_39df.sort_values('melanoma_39', ascending=False)
sortedmelanoma_40 = melanoma_40df.sort_values('melanoma_40', ascending=False)

# %%
sortedmelanoma_41 = melanoma_41df.sort_values('melanoma_41', ascending=False)
sortedmelanoma_42 = melanoma_42df.sort_values('melanoma_42', ascending=False)
sortedmelanoma_43 = melanoma_43df.sort_values('melanoma_43', ascending=False)
sortedmelanoma_44 = melanoma_44df.sort_values('melanoma_44', ascending=False)
sortedmelanoma_45 = melanoma_45df.sort_values('melanoma_45', ascending=False)
sortedmelanoma_46 = melanoma_46df.sort_values('melanoma_46', ascending=False)
sortedmelanoma_47 = melanoma_47df.sort_values('melanoma_47', ascending=False)
sortedmelanoma_48 = melanoma_48df.sort_values('melanoma_48', ascending=False)
sortedmelanoma_49 = melanoma_49df.sort_values('melanoma_49', ascending=False)
sortedmelanoma_50 = melanoma_50df.sort_values('melanoma_50', ascending=False)

# %%
sortedmelanoma_51 = melanoma_51df.sort_values('melanoma_51', ascending=False)
sortedmelanoma_52 = melanoma_52df.sort_values('melanoma_52', ascending=False)
sortedmelanoma_53 = melanoma_53df.sort_values('melanoma_53', ascending=False)
sortedmelanoma_54 = melanoma_54df.sort_values('melanoma_54', ascending=False)
sortedmelanoma_55 = melanoma_55df.sort_values('melanoma_55', ascending=False)
sortedmelanoma_56 = melanoma_56df.sort_values('melanoma_56', ascending=False)
sortedmelanoma_57 = melanoma_57df.sort_values('melanoma_57', ascending=False)
sortedmelanoma_58 = melanoma_58df.sort_values('melanoma_58', ascending=False)
sortedmelanoma_59 = melanoma_59df.sort_values('melanoma_59', ascending=False)
sortedmelanoma_60 = melanoma_60df.sort_values('melanoma_60', ascending=False)

# %%
sortedmelanoma_61 = melanoma_61df.sort_values('melanoma_61', ascending=False)
sortedmelanoma_62 = melanoma_62df.sort_values('melanoma_62', ascending=False)
sortedmelanoma_63 = melanoma_63df.sort_values('melanoma_63', ascending=False)
sortedmelanoma_64 = melanoma_64df.sort_values('melanoma_64', ascending=False)
sortedmelanoma_65 = melanoma_65df.sort_values('melanoma_65', ascending=False)
sortedmelanoma_66 = melanoma_66df.sort_values('melanoma_66', ascending=False)
sortedmelanoma_67 = melanoma_67df.sort_values('melanoma_67', ascending=False)
sortedmelanoma_68 = melanoma_68df.sort_values('melanoma_68', ascending=False)

# %%
sortedmelanoma_7 = melanoma_7df.sort_values('melanoma_7', ascending=False)
sortedmelanoma_8 = melanoma_8df.sort_values('melanoma_8', ascending=False)
sortedmelanoma_9 = melanoma_9df.sort_values('melanoma_9', ascending=False)

# %%
sortedmelanoma_9
# Out:
#                Token  melanoma_9
# 137352           C>T     23028.0
# 137354           T>C     16593.0
# 137353           T>A     12219.0
# 137355           T>G     10037.0
# 137350           C>A      9882.0
# 0        3AAAAAAAAAA      3615.0
# 68289    3TTTTTTTTTT      3505.0
# 137351           C>G      3203.0
# 68290    5AAAAAAAAAA      2114.0
# 137349   5TTTTTTTTTT      1676.0
# 53741    3TATATATATA       928.0
# 121114   5TATATATATA       872.0
# 14784    3ATATATATAT       759.0
# 5602     3ACACACACAC       734.0
# 117209   5GTGTGTGTGT       720.0
# 83217    5ATATATATAT       702.0
# 63080    3TGTGTGTGTG       565.0
# 88479    5CACACACACA       558.0
# 131190   5TGTGTGTGTG       329.0
# 19951    3CACACACACA       300.0
# 99672    5CTCTCTCTCT       278.0
# 9502     3AGAGAGAGAG       262.0
# 134013   5TTCTTTCTTT       254.0
# 49731    3GTGTGTGTGT       233.0
# 67874    3TTTTCTTTTT       232.0
# 74264    5ACACACACAC       223.0
# 1064     3AAAGAAAGAA       210.0
# ...

# %%
sortedlungad_df= pd.DataFrame()

# %%
pieces = 
{'lungad_1': sortedlungad_1, 'lungad_2': sortedlungad_2, 'lungad_3': sortedlungad_3, 'lungad_4': sortedlungad_4,'lungad_5': sortedlungad_5,
'lungad_6': sortedlungad_6,'lungad_7': sortedlungad_7, 
'lungad_8': sortedlungad_8,'lungad_9': sortedlungad_9,
'lungad_10': sortedlungad_10,'lungad_11': sortedlungad_11,
'lungad_12': sortedlungad_12,'lungad_13': sortedlungad_13,
'lungad_14': sortedlungad_14,'lungad_15': sortedlungad_15,
'lungad_16': sortedlungad_16, 'lungad_17': sortedlungad_17, 'lungad_18': sortedlungad_18, 'lungad_19': sortedlungad_19,'lungad_20': sortedlungad_20,
'lungad_21': sortedlungad_21,'lungad_22': sortedlungad_22, 
'lungad_23': sortedlungad_23,'lungad_24': sortedlungad_24,
'lungad_25': sortedlungad_25,'lungad_26': sortedlungad_26,
'lungad_27': sortedlungad_27,'lungad_28': sortedlungad_28,
'lungad_29': sortedlungad_29,'lungad_30': sortedlungad_30,
'lungad_31': sortedlungad_31,'lungad_32': sortedlungad_32,'lungad_33': sortedlungad_33,
'lungad_34': sortedlungad_34,'lungad_35': sortedlungad_35,
'lungad_36': sortedlungad_36, 'lungad_37': sortedlungad_37, 'lungad_38': sortedlungad_38, 'lungad_39': sortedlungad_39,'lungad_40': sortedlungad_40,
'lungad_41': sortedlungad_41,'lungad_42': sortedlungad_42
}

# %%
lungadresult= pd.concat(pieces)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f4e4590f017> in <module>()
# ----> 1 result = pd.concat(pieces)
#
# NameError: name 'pd' is not defined

# %%
pieces2 = {'melanoma_1': sortedmelanoma_1, 'melanoma_2': sortedmelanoma_2, 'melanoma_3': sortedmelanoma_3, 'melanoma_4': sortedmelanoma_4,'melanoma_5': sortedmelanoma_5,
'melanoma_6': sortedmelanoma_6,'melanoma_7': sortedmelanoma_7, 
'melanoma_8': sortedmelanoma_8,'melanoma_9': sortedmelanoma_9,
'melanoma_10': sortedmelanoma_10,'melanoma_11': sortedmelanoma_11,
'melanoma_12': sortedmelanoma_12,'melanoma_13': sortedmelanoma_13,
'melanoma_14': sortedmelanoma_14,'melanoma_15': sortedmelanoma_15,
'melanoma_16': sortedmelanoma_16, 'melanoma_17': sortedmelanoma_17, 'melanoma_18': sortedmelanoma_18, 'melanoma_19': sortedmelanoma_19,'melanoma_20': sortedmelanoma_20,
'melanoma_21': sortedmelanoma_21,'melanoma_22': sortedmelanoma_22, 
'melanoma_23': sortedmelanoma_23,'melanoma_24': sortedmelanoma_24,
'melanoma_25': sortedmelanoma_25,'melanoma_26': sortedmelanoma_26,
'melanoma_27': sortedmelanoma_27,'melanoma_28': sortedmelanoma_28,
'melanoma_29': sortedmelanoma_29,'melanoma_30': sortedmelanoma_30,
'melanoma_31': sortedmelanoma_31,
'melanoma_32': sortedmelanoma_32,'melanoma_33': sortedmelanoma_33,
'melanoma_34': sortedmelanoma_34,'melanoma_35': sortedmelanoma_35,
'melanoma_36': sortedmelanoma_36, 'melanoma_37': sortedmelanoma_37, 'melanoma_38': sortedmelanoma_38, 'melanoma_39': sortedmelanoma_39,'melanoma_40': sortedmelanoma_40,
'melanoma_41': sortedmelanoma_41,'melanoma_42': sortedmelanoma_42, 'melanoma_43': sortedmelanoma_43,
'melanoma_44': sortedmelanoma_44,'melanoma_45': sortedmelanoma_45,
'melanoma_46': sortedmelanoma_46, 'melanoma_47': sortedmelanoma_47, 'melanoma_48': sortedmelanoma_48, 'melanoma_49': sortedmelanoma_49,'melanoma_50': sortedmelanoma_50,'melanoma_51': sortedmelanoma_51,'melanoma_52': sortedmelanoma_52, 'melanoma_53': sortedmelanoma_53,
'melanoma_54': sortedmelanoma_54,'melanoma_55': sortedmelanoma_55,
'melanoma_56': sortedmelanoma_56, 'melanoma_57': sortedmelanoma_57, 'melanoma_58': sortedmelanoma_58, 'melanoma_59': sortedmelanoma_59,'melanoma_60': sortedmelanoma_60, melanoma_61': sortedmelanoma_61,'melanoma_62': sortedmelanoma_62, 'melanoma_63': sortedmelanoma_63,
'melanoma_64': sortedmelanoma_64,'melanoma_65': sortedmelanoma_65,
'melanoma_66': sortedmelanoma_66, 'melanoma_67': sortedmelanoma_67, 'melanoma_68': sortedmelanoma_68

}

# %%
melanomaresult= pd.concat(pieces2)

# %%
lungadresult.to_csv(lungadsorted, sep=',')
melanomaresult.to_csv(melanomasorted, sep=',')
